# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_re = pd.read_pickle("df_re.pkl")
df_re.head()
# Out:
#                   eid                           doi                pii  \
# 0  2-s2.0-85109755005  10.1016/j.ijepes.2021.107370  S0142061521006098
# 1  2-s2.0-85109460674     10.1016/j.aej.2021.06.026  S1110016821003872
# 2  2-s2.0-85109432210     10.1016/j.aej.2021.06.028  S1110016821003902
# 3  2-s2.0-85108730066     10.1016/j.ces.2021.116871  S000925092100436X
# 4  2-s2.0-85108598105     10.1016/j.ces.2021.116862  S0009250921004279
#
#   pubmed_id                                              title subtype  \
# 0      None  Generation maintenance scheduling with renewab...      ar
# 1      None  A review on segregation of various high gain c...      re
# 2      None  Application of polynomial regression and MILP ...      ar
# 3      None  CO<inf>2</inf> methanation in a shell and tube...      ar
# 4      None  Reverse traveling microwave reactor – Modellin...      ar
#
#   subtypeDescription            creator                                 afid  \
# ...

# %%
df_re.loc[df_re["title"].str.contains("CNN") == True]["title"].values
# Out:
# array(['Forecasting model of photovoltaic power based on KPCA-MCS-DCNN',
#        'A CNN-Based Warning Information Preprocessing Method for Power Grid Fault Diagnosis Analytical Model',
#        'State of Energy Prediction in Renewable Energy-driven Mobile Edge Computing using CNN-LSTM Networks',
#        'Prediction of Direct Normal Irradiation Based on CNN-LSTM Model',
#        'Toward the Prediction Level of Situation Awareness for Electric Power Systems Using CNN-LSTM Network',
#        'A convolution neural network (CNN) based deep learning neural network forecast model for wind energy prediction'],
#       dtype=object)

# %%
df_re.loc[4102]
# Out:
# eid                                                   2-s2.0-85092388756
# doi                                              10.1145/3404716.3404719
# pii                                                                 None
# pubmed_id                                                           None
# title                  Prediction of Direct Normal Irradiation Based ...
# subtype                                                               cp
# subtypeDescription                                      Conference Paper
# creator                                                         Zhang C.
# afid                                                   60088567;60019499
# affilname              Beijing Information Science &amp; Technology U...
# affiliation_city                                         Beijing;Beijing
# affiliation_country                                          China;China
# author_count                                                           4
# ...
