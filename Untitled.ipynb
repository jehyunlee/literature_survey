# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

X = np.arange(10)
Y1 = X+7
Y2 = 17-X

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()

ax1.bar(X, Y1)
ax2.plot(X, Y2, 'o-', c='r')
