# %%
from copy import deepcopy
import numpy as np
import pandas as pd
import calendar
from pybliometrics.scopus import ScopusSearch
from pybliometrics.scopus import AbstractRetrieval

from tqdm import tqdm

pd.options.display.max_columns = 30

filename = "./210803/BIPV_ML.txt"
filename_rooftop = "./210803/rooftop_ML.txt"

# %%
df_bipv = pd.read_pickle("./210803/df_bipv.pkl")
df_bipv.head(3)
# Out:
#                   eid                           doi                pii  \
# 0  2-s2.0-85110764627  10.1016/j.renene.2021.07.075  S0960148121010806
# 1  2-s2.0-85110299293  10.1016/j.energy.2021.121415  S0360544221016637
# 2  2-s2.0-85107321575    10.1038/s41467-021-23592-0               None
#
#   pubmed_id                                              title subtype  \
# 0      None  Markov chains estimation of the optimal period...      ar
# 1      None  Stochastic modelling of variable renewables in...      ar
# 2  34059672  Revealing composition and structure dependent ...      ar
#
#   subtypeDescription             creator                afid  \
# 0            Article  Sánchez-Barroso G.  60017838;126596986
# 1            Article           Seljom P.  60004205;101126845
# 2            Article             Lian W.  60089931;125236348
#
#                                            affilname   affiliation_city  \
# 0     Universidad de Extremadura;InnoDesarrollo S.L.    Badajoz;Badajoz
# 1  SINTEF Foundation for Scientific and Industria...  Trondheim;Kjeller
# 2  Hefei National Laboratory for Physical Science...        Hefei;Hefei
#
#   affiliation_country author_count  \
# 0         Spain;Spain            4
# 1       Norway;Norway            5
# 2         China;China            8
#
#                                         author_names  \
# 0  Sánchez-Barroso, Gonzalo;González-Domínguez, J...
# 1  Seljom, Pernille;Kvalbein, Lisa;Hellemo, Lars;...
# 2  Lian, Weitao;Jiang, Chenhui;Yin, Yiwei;Tang, R...
#
#                                           author_ids  ...      issn  \
# 0    57216405703;57216406595;57197703890;57197479389  ...  09601481
# 1  37108388300;57226090492;26767755100;2043623340...  ...  03605442
# 2  57204036372;57202454733;57203962991;5719647276...  ...      None
#
#      source_id     eIssn aggregationType volume issueIdentifier  \
# 0        27569  18790682         Journal    179            None
# 1        29348      None         Journal    236            None
# 2  19700182758  20411723         Journal     12               1
#
#   article_number pageRange                                        description  \
# 0           None   537-549  The European Dehesa has a very high potential ...
# 1         121415      None  Variable electricity generation from wind and ...
# 2           3260      None  Antimony trisulfide (Sb2S3) is a kind of emerg...
#
#                                         authkeywords citedby_count openaccess  \
# 0  Cleaning frequency | Cleaning photovoltaic sys...             0          1
# 1  Energy-system modelling | Satellite-data | Sce...             0          0
# 2                                               None             0          1
#
#   fund_acr   fund_no                                       fund_sponsor
# 0      ESF   PD18047                               European Social Fund
# 1     None    268097                               Norges Forskningsråd
# 2     IUSS  22005293  National Outstanding Youth Science Fund Projec...
#
# [3 rows x 34 columns]

# %%
df_bipv.loc[0]
# Out:
# eid                                                   2-s2.0-85110764627
# doi                                         10.1016/j.renene.2021.07.075
# pii                                                    S0960148121010806
# pubmed_id                                                           None
# title                  Markov chains estimation of the optimal period...
# subtype                                                               ar
# subtypeDescription                                               Article
# creator                                               Sánchez-Barroso G.
# afid                                                  60017838;126596986
# affilname                 Universidad de Extremadura;InnoDesarrollo S.L.
# affiliation_city                                         Badajoz;Badajoz
# affiliation_country                                          Spain;Spain
# author_count                                                           4
# author_names           Sánchez-Barroso, Gonzalo;González-Domínguez, J...
# author_ids               57216405703;57216406595;57197703890;57197479389
# author_afids                        60017838;60017838;60017838;126596986
# coverDate                                                     2021-12-01
# coverDisplayDate                                           December 2021
# publicationName                                         Renewable Energy
# issn                                                            09601481
# source_id                                                          27569
# eIssn                                                           18790682
# aggregationType                                                  Journal
# volume                                                               179
# issueIdentifier                                                     None
# article_number                                                      None
# pageRange                                                        537-549
# description            The European Dehesa has a very high potential ...
# authkeywords           Cleaning frequency | Cleaning photovoltaic sys...
# citedby_count                                                          0
# openaccess                                                             1
# fund_acr                                                             ESF
# fund_no                                                          PD18047
# fund_sponsor                                        European Social Fund
# Name: 0, dtype: object

# %%
df_ab = pd.read_pickle("./210803/df_ab.pkl")
df_ab.shape
# Out:
# (14385, 29)

# %%
# publication type
# "J" = Journal
# "B" = Book
# "S" = Series
# "P" = Patent
dict_pubtype = {'ar': 'J',    # 'Article',
                'ab': 'J',    # 'Abstract Report',
                'bk': 'B',    # 'Book',
                'ch': 'B',    # 'Book Chapter',
                'bz': 'J',    # 'Business Article',
                'cp': 'J',    # 'Conference Paper',
                'cr': 'J',    # 'Conference Review',
                'dp': 'J',    # 'Data Paper ',
                'ed': 'S',    # 'Editorial',
                'er': 'J',    # 'Erratum',
                'le': 'J',    # 'Letter',
                'no': 'S',    # 'Note',
                'pr': 'S',    # 'Press Release',
                'rp': 'J',    # 'Report',
                'tb': 'J',    # 'Retracted',
                're': 'J',    # 'Review',
                'sh': 'J',    # 'Short Survey'
                'ip': 'P'     # 'Patent' 
               }

# documentation type
dict_docutype = {'ar': 'Article',
                 'ab': 'Abstract Report',
                 'bk': 'Book',
                 'ch': 'Book Chapter',
                 'bz': 'Business Article',
                 'cp': 'Conference Paper',
                 'cr': 'Conference Review',
                 'dp': 'Data Paper ',
                 'ed': 'Editorial',
                 'er': 'Erratum',
                 'le': 'Letter',
                 'no': 'Note',
                 'pr': 'Press Release',
                 'rp': 'Report',
                 'tb': 'Retracted',
                 're': 'Review',
                 'sh': 'Short Survey',
                 'ip': 'Patent'
                }

# text cleaning
dict_clean_text = {"&amp;": "&", 
                   "&nbsp;": " ", 
                   "&lt;": "<",
                   "&gt;": ">"
                  }
def get_clean_text(text):
    for k, v in dict_clean_text.items():
        text = text.replace(k, v)
    return text

# %%
# all

import os, calendar

with open(filename, "w") as datafile:
    datafile.write("FN Clarivate Analytics Web of Science\nVR 1.0")
    
    for art in df_ab.index:
        df_row = df_ab.loc[art]
        
        # 1. PT: publication type
        pubtype_ = dict_pubtype[df_row['PT']]
        datafile.write(f"\nPT {pubtype_}")
        
        # 2. AU: author names
        author_name_ = df_row['AU']
        author_name = "\nAU "
        if all(author_name_):
            author_name += "\n   ".join(author_name_)
            
        datafile.write(author_name)
        
        # 3. AF: affiliations
        affiliation_ = df_row['AF']
        affiliation = "\nAF "
        if all(affiliation_):
            affiliation += "\n   ".join(affiliation_)
        datafile.write(affiliation)
        
        # 4. TI: document title
        title = '\nTI '
        title_ = df_row['TI']
        if title_:
            title += get_clean_text(title_)
        datafile.write(title)
        
        # 5. SO: publication name
        so = '\nSO '
        so_ = df_row['SO']
        if so_:
            so += get_clean_text(so_)
        datafile.write(so)
        
        # 6. LA : Language
        datafile.write("\nLA " + df_row["LA"])
        
        # 7. DT : Document Type
        docutype_ = dict_docutype[df_row['DT']]
        datafile.write(f"\nDT {docutype_}")
        
        # 8. DE : Author Keywords
        de_ = df_row['DE']
        datafile.write(f"\nDE {de_}")
        
        # 9. ID : Keyword Plus
        id_ = df_row['ID']
        datafile.write(f"\nID {id_}")
        
        # 10. AB: Abstract
        ab_ = df_row['AB']
        datafile.write(f"\nAB {ab_}")
        
        # 11. C1 : Author Address
        c1_ = df_row['C1']
        c1 = [f"[{'; '.join(c[1])}] {', '.join(c[2].split(', ')[1:])}" for c in c1_]
        c1 = ".\n   ".join(c1) + "."
        datafile.write("\nC1 " + c1)
        
        # 12. RP : Reprint Address
        datafile.write("\nRP None")

        # 13. EM : E-mail Address
        datafile.write("\nEM None")
        
        # 14. CR : Cited References
        cr_ = df_row["CR"]
        if len(cr_) > 0:
            cr_[0] = "  " + cr_[0][2:]
            cr_ = [c for c in cr_ if len(c) > 5]
            cr_ = [c.lstrip(" ") for c in cr_ if (c[3] != ',') or ("DOI" in c)]
        datafile.write("\nCR "+"\n   ".join(cr_))
        
        # 15. NR : Cited Reference Count
        datafile.write(f"\nNR {df_row['NR']}")
        
        # 16. TC : Web of Science Core Collection Times Cited Count
        datafile.write(f"\nTC {df_row['TC']}")
        
        # 17. Z9 : Total Times Cited Count
        z9_ = df_row['Z9']
        datafile.write(f"\nZ9 {z9_}")
        
        # 18. U1 : Usage Count (Last 180 Days)
        # 19. U2 : Usage Count (Since 2013)
        # 20. PU : Publisher = ELSEVIER SCI LTD
        # 21. PI : Publisher City = OXFORD
        # 22. PA : Publisher Address = THE BOULEVARD, LANGFORD LANE, KIDLINGTON, OXFORD OX5 1GB, OXON, ENGLAND
        # 23. SN : International Standard Serial Number (ISSN) = 0959-6526
        sn_ = df_row["SN"]
        datafile.write(f"\nSN {sn_}")
        
        # 24. EI : Electronic International Standard Serial Number (eISSN) = 1879-1786
        # 25. J9 : 29-Character Source Abbreviation = J CLEAN PROD
        j9_ = df_row["J9"]
        datafile.write(f"\nJ9 {j9_}")
        
        # 26. JI : ISO Source Abbreviation = J. Clean Prod.
        ji_ = df_row["JI"]
        datafile.write(f"\nJI {ji_}")
        
        # 27. PD : Publication Date = JUL 1
        pd_ = df_row["PD"]
        datafile.write(f"\nPD {pd_}")
        
        # 28. PY : Publication Year = 2020
        py_ = df_row["PY"]
        datafile.write(f"\nPY {py_}")
        
        # 29. VL : Volumn = 260
        vl_ = df_row["VL"]
        datafile.write(f"\nVL {vl_}")
        
        # 30. AR : Article Number = 121059
        ar_ = df_row["AR"]
        datafile.write(f"\nAR {ar_}")
        
        # 31. DI : Digital Object Identifier = 10.1016/j.jclepro.2020.121059
        doi_ = df_row["DI"]
        datafile.write(f"\nDI {doi_}")
        
        # 32. PG : Page Count = 14
        # 33. WC : Web of Science Categories = Green & Sustainable Science & Technology; Engineering, Environmental; Environmental Sciences
        # 34. SC : Research Areas = Science & Technology - Other Topics; Engineering; Environmental Sciences & Ecology
        sc_ = df_row["SC"]
        datafile.write(f"\nSC {sc_}")
        
        # end 
        datafile.write(f"\nER\n")
        
    datafile.write("\nEF\n")

# %%
df_ab.query("is_rooftop == True")
# Out:
#                       eid  PT  \
# 0      2-s2.0-85110764627  ar
# 3      2-s2.0-85107176116  ar
# 34     2-s2.0-85108691578  ar
# 83     2-s2.0-85107622660  ar
# 89     2-s2.0-85105000579  ar
# ...                   ...  ..
# 14192   2-s2.0-0023545718  ar
# 14197   2-s2.0-0023382414  ar
# 14226   2-s2.0-0022329766  cp
# 14288   2-s2.0-0021774758  cp
# 14326   2-s2.0-0019115442  cp
#
#                                                       AU  \
# 0      [Sanchez-Barroso G., Gonzalez-Dominguez J., Ga...
# 3      [Perrakis G., Tasolamprou A.C., Kenanakis G., ...
# 34        [Christiaanse T.V., Loonen R.C.G.M., Evins R.]
# 83     [Hong Y., Ezeh C.I., Deng W., Hong S.-H., Ma Y...
# 89          [Rahmani F., Robinson M.A., Barzegaran M.R.]
# ...                                                  ...
# 14192                                        [Muneer T.]
# 14197         [Lindquist S.-E., Lindgren A., Leygraf C.]
# 14226                                [Ingersoll John G.]
# 14288  [Girgis Magdy A., Chandra Subrato, Khattar Muk...
# 14326                     [Plunkett B.C., Lasswell P.G.]
#
#                                                       AF  \
# 0      [Sánchez-Barroso, Gonzalo, González-Domínguez,...
# 3      [Perrakis, George, Tasolamprou, Anna C., Kenan...
# 34     [Christiaanse, T. V., Loonen, R. C.G.M., Evins...
# 83     [Hong, Y., Ezeh, Collins I., Deng, W., Hong, S...
# 89     [Rahmani, Fatemeh, Robinson, Mark Alan, Barzeg...
# ...                                                  ...
# 14192                                       [Muneer, T.]
# 14197  [Lindquist, Sten Eric, Lindgren, Anders, Leygr...
# 14226                               [Ingersoll, John G.]
# 14288  [Girgis, Magdy A., Chandra, Subrato, Khattar, ...
# 14326         [Plunkett, Brian C., Lasswell, Patrick G.]
#
#                                                       TI  \
# 0      Markov chains estimation of the optimal period...
# 3      Combined nano and micro structuring for enhanc...
# 34     Techno-economic optimization for grid-friendly...
# 83     Coordinated energy-environmental-economic opti...
# 89     Cool roof coating impact on roof-mounted photo...
# ...                                                  ...
# 14192  Hourly diffuse and global solar irradiation: F...
# 14197  Effects of electrochemical reduction of polycr...
# 14226  SIMPLIFIED PREDICTION OF ANNUAL ENERGY GENERAT...
# 14288  THERMAL PERFORMANCE OF THE FSEC PV HOUSE UNDER...
# 14326         Laser scanning of experimental solar cells
#
#                                                       SO  \
# 0                                       Renewable Energy
# 3                                     Scientific Reports
# 34       Sustainable Energy Technologies and Assessments
# 83                      Energy Conversion and Management
# 89     International Journal of Electrical Power and ...
# ...                                                  ...
# 14192  Building Services Engineering Research & Techn...
# 14197                             Solar Energy Materials
# 14226  Conference Record of the IEEE Photovoltaic Spe...
# 14288                                               None
# 14326  Proceedings of SPIE - The International Societ...
#
#                                                   SO_abb       LA  DT  \
# 0                                          Renew. Energy  English  ar
# 3                                              Sci. Rep.  English  ar
# 34                   Sustainable Energy Technol. Assess.  English  ar
# 83                               Energy Convers. Manage.  English  ar
# 89                        Int J Electr Power Energy Syst  English  ar
# ...                                                  ...      ...  ..
# 14192                         Build Serv Eng Res Technol  English  ar
# 14197                                               None  English  ar
# 14226  Conference Record of the IEEE Photovoltaic Spe...  English  cp
# 14288                                               None  English  cp
# 14326                          Proc SPIE Int Soc Opt Eng  English  cp
#
#                                                       DE    ID  \
# 0      Cleaning frequency; Cleaning photovoltaic syst...  None
# 3                                                   None  None
# 34     Bi-level optimization; British Columbia; Energ...  None
# 83     Life-cycle cost analysis; Low-rise; Office bui...  None
# 89     Cool roof coating; DC-coupled solar photovolta...  None
# ...                                                  ...   ...
# 14192                                               None  None
# 14197                                               None  None
# 14226                                               None  None
# 14288                                               None  None
# 14326                                               None  None
#
#                                                       AB  \
# 0      © 2021 The AuthorsThe European Dehesa has a ve...
# 3      © 2021, The Author(s).Outdoor devices comprisi...
# 34     © 2021 Elsevier LtdHigh levels of non-dispatch...
# 83     © 2021 Elsevier LtdGiven that energy-efficienc...
# 89     © 2021 Elsevier LtdCool-roofing is effective i...
# ...                                                  ...
# 14192  Following the correlation equations between ho...
# 14197  Polycrystalline TiO2 film electrodes prepared ...
# 14226  A simplified but accurate model has been devel...
# 14288  An energy efficient photovoltaic (PV) house ha...
# 14326  Standard measurements of photovoltaic paramete...
#
#                                                       C1    RP    EM  \
# 0      [[[57216405703, 57216406595, 57197703890], [Sa...  None  None
# 3      [[[25925551900, 21234204900], [Tasolamprou A.C...  None  None
# 34     [[[55504415000], [Loonen R.C.G.M.], 60032882, ...  None  None
# 83     [[[57191907391, 56647024700, 57222633102], [De...  None  None
# 89     [[[57198277655, 26535502400], [Rahmani F., Bar...  None  None
# ...                                                  ...   ...   ...
# 14192  [[[7006647735], [Muneer T.], 60011885, Robert ...  None  None
# 14197  [[[7004947028], [Leygraf C.], 60079613, Swerea...  None  None
# 14226  [[[57197097430], [Ingersoll John G.], 60005304...  None  None
# 14288  [[[7006352007, 7401671386, 7004438367], [Girgi...  None  None
# 14326  [[[6603965237, 6602782171], [Plunkett B.C., La...  None  None
#
#                                                       CR  NR  TC  Z9  \
# 0      [   , 2012,    , 2020, Spain's Electricity Gri...  44   0   0
# 3      [   Raman, A.P.; Anoma, M.A.; Zhu, L.; Rephael...  45   0   0
# 34     [   Wiginton, L.K.; Nguyen, H.T.; Pearce, J.M....  36   0   0
# 83     [   Nägeli, C., 2019, Build Environ,    Zheng,...  40   0   0
# 89     [   Akbari, H.; Levinson, R., 2008, Adv Build ...  27   0   0
# ...                                                  ...  ..  ..  ..
# 14192  [   Muneer, T.; Saluja, G.S., 1986, Building S...   8   9   9
# 14197  [   , 1979, Journal of The Electrochemical Soc...  24  21  21
# 14226                                                 []  12   4   4
# 14288                                                 []   4   0   0
# 14326  [   Rothwarf, A., 1979, Photovoltaic Materials...   6   2   2
#
#                       SN                                                 J9  \
# 0      18790682 09601481                                      RENEW. ENERGY
# 3               20452322                                          SCI. REP.
# 34              22131388                SUSTAINABLE ENERGY TECHNOL. ASSESS.
# 83              01968904                            ENERGY CONVERS. MANAGE.
# 89              01420615                     INT J ELECTR POWER ENERGY SYST
# ...                  ...                                                ...
# 14192  14770849 01436244                         BUILD SERV ENG RES TECHNOL
# 14197           01651633                                               NONE
# 14226           01608371  CONFERENCE RECORD OF THE IEEE PHOTOVOLTAIC SPE...
# 14288               None                                               NONE
# 14326  1996756X 0277786X                          PROC SPIE INT SOC OPT ENG
#
#                                                       JI      PD  PY    VL  \
# 0                                          Renew. Energy   DEC 1  01   179
# 3                                              Sci. Rep.   DEC 1  01    11
# 34                   Sustainable Energy Technol. Assess.   OCT 1  01    47
# 83                               Energy Convers. Manage.   SEP 1  01   243
# 89                        Int J Electr Power Energy Syst   SEP 1  01   130
# ...                                                  ...     ...  ..   ...
# 14192                         Build Serv Eng Res Technol   JAN 1  01     8
# 14197                                               None   JAN 1  01    15
# 14226  Conference Record of the IEEE Photovoltaic Spe...   DEC 1  01  None
# 14288                                               None   JAN 1  01  None
# 14326                          Proc SPIE Int Soc Opt Eng  NOV 25  25   248
#
#            AR                              DI  \
# 0        None    10.1016/j.renene.2021.07.075
# 3       11552      10.1038/s41598-021-91061-1
# 34     101320      10.1016/j.seta.2021.101320
# 83     114327  10.1016/j.enconman.2021.114327
# 89     106932    10.1016/j.ijepes.2021.106932
# ...       ...                             ...
# 14192    None      10.1177/014362448700800403
# 14197    None    10.1016/0165-1633(87)90057-8
# 14226    None                            None
# 14288    None                            None
# 14326    None               10.1117/12.970599
#
#                                                       SC  is_rooftop
# 0      Renewable Energy, Sustainability and the Envir...        True
# 3                                      Multidisciplinary        True
# 34     Renewable Energy, Sustainability and the Envir...        True
# 83     Renewable Energy, Sustainability and the Envir...        True
# 89     Energy Engineering and Power Technology; Elect...        True
# ...                                                  ...         ...
# 14192                          Building and Construction        True
# 14197                                  Engineering (all)        True
# 14226  Control and Systems Engineering; Industrial an...        True
# 14288                                  Engineering (all)        True
# 14326  Electronic, Optical and Magnetic Materials; Co...        True
#
# [921 rows x 29 columns]

# %%
# rooftop

import os, calendar

with open(filename_rooftop, "w") as datafile:
    datafile.write("FN Clarivate Analytics Web of Science\nVR 1.0")
    
    df_ab_rooftop = df_ab.query("is_rooftop == True")
    for art in df_ab_rooftop.index:
        df_row = df_ab.loc[art]
        
        # 1. PT: publication type
        pubtype_ = dict_pubtype[df_row['PT']]
        datafile.write(f"\nPT {pubtype_}")
        
        # 2. AU: author names
        author_name_ = df_row['AU']
        author_name = "\nAU "
        if all(author_name_):
            author_name += "\n   ".join(author_name_)
            
        datafile.write(author_name)
        
        # 3. AF: affiliations
        affiliation_ = df_row['AF']
        affiliation = "\nAF "
        if all(affiliation_):
            affiliation += "\n   ".join(affiliation_)
        datafile.write(affiliation)
        
        # 4. TI: document title
        title = '\nTI '
        title_ = df_row['TI']
        if title_:
            title += get_clean_text(title_)
        datafile.write(title)
        
        # 5. SO: publication name
        so = '\nSO '
        so_ = df_row['SO']
        if so_:
            so += get_clean_text(so_)
        datafile.write(so)
        
        # 6. LA : Language
        datafile.write("\nLA " + df_row["LA"])
        
        # 7. DT : Document Type
        docutype_ = dict_docutype[df_row['DT']]
        datafile.write(f"\nDT {docutype_}")
        
        # 8. DE : Author Keywords
        de_ = df_row['DE']
        datafile.write(f"\nDE {de_}")
        
        # 9. ID : Keyword Plus
        id_ = df_row['ID']
        datafile.write(f"\nID {id_}")
        
        # 10. AB: Abstract
        ab_ = df_row['AB']
        datafile.write(f"\nAB {ab_}")
        
        # 11. C1 : Author Address
        c1_ = df_row['C1']
        c1 = [f"[{'; '.join(c[1])}] {', '.join(c[2].split(', ')[1:])}" for c in c1_]
        c1 = ".\n   ".join(c1) + "."
        datafile.write("\nC1 " + c1)
        
        # 12. RP : Reprint Address
        datafile.write("\nRP None")

        # 13. EM : E-mail Address
        datafile.write("\nEM None")
        
        # 14. CR : Cited References
        cr_ = df_row["CR"]
        if len(cr_) > 0:
            cr_[0] = "  " + cr_[0][2:]
            cr_ = [c for c in cr_ if len(c) > 5]
            cr_ = [c.lstrip(" ") for c in cr_ if (c[3] != ',') or ("DOI" in c)]
        datafile.write("\nCR "+"\n   ".join(cr_))
        
        # 15. NR : Cited Reference Count
        datafile.write(f"\nNR {df_row['NR']}")
        
        # 16. TC : Web of Science Core Collection Times Cited Count
        datafile.write(f"\nTC {df_row['TC']}")
        
        # 17. Z9 : Total Times Cited Count
        z9_ = df_row['Z9']
        datafile.write(f"\nZ9 {z9_}")
        
        # 18. U1 : Usage Count (Last 180 Days)
        # 19. U2 : Usage Count (Since 2013)
        # 20. PU : Publisher = ELSEVIER SCI LTD
        # 21. PI : Publisher City = OXFORD
        # 22. PA : Publisher Address = THE BOULEVARD, LANGFORD LANE, KIDLINGTON, OXFORD OX5 1GB, OXON, ENGLAND
        # 23. SN : International Standard Serial Number (ISSN) = 0959-6526
        sn_ = df_row["SN"]
        datafile.write(f"\nSN {sn_}")
        
        # 24. EI : Electronic International Standard Serial Number (eISSN) = 1879-1786
        # 25. J9 : 29-Character Source Abbreviation = J CLEAN PROD
        j9_ = df_row["J9"]
        datafile.write(f"\nJ9 {j9_}")
        
        # 26. JI : ISO Source Abbreviation = J. Clean Prod.
        ji_ = df_row["JI"]
        datafile.write(f"\nJI {ji_}")
        
        # 27. PD : Publication Date = JUL 1
        pd_ = df_row["PD"]
        datafile.write(f"\nPD {pd_}")
        
        # 28. PY : Publication Year = 2020
        py_ = df_row["PY"]
        datafile.write(f"\nPY {py_}")
        
        # 29. VL : Volumn = 260
        vl_ = df_row["VL"]
        datafile.write(f"\nVL {vl_}")
        
        # 30. AR : Article Number = 121059
        ar_ = df_row["AR"]
        datafile.write(f"\nAR {ar_}")
        
        # 31. DI : Digital Object Identifier = 10.1016/j.jclepro.2020.121059
        doi_ = df_row["DI"]
        datafile.write(f"\nDI {doi_}")
        
        # 32. PG : Page Count = 14
        # 33. WC : Web of Science Categories = Green & Sustainable Science & Technology; Engineering, Environmental; Environmental Sciences
        # 34. SC : Research Areas = Science & Technology - Other Topics; Engineering; Environmental Sciences & Ecology
        sc_ = df_row["SC"]
        datafile.write(f"\nSC {sc_}")
        
        # end 
        datafile.write(f"\nER\n")
        
    datafile.write("\nEF\n")
