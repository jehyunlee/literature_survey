# %% [markdown]
# * code by Sihyun You (2021.12.28.)
# * edit by Jehyun Lee (2021.12.30.)
# * revised for mrnIF by Jehyun Lee (2022.01.08.)
# * bugfix for mrnIF by Jehyun Lee (2022.01.20.)
# * using applicants submitted Eng. name (2022.06.17.)
# * ready for Streamlit (2023.01.02.)

# %% [markdown]
# # Environment settings

# %% [markdown]
# * import libraries

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from pybliometrics.scopus import ScopusSearch
from bs4 import BeautifulSoup
import requests, json
from docx import Document
from copy import deepcopy

# %% [markdown]
# * Scopus API Keys

# %%
from my_apikeys import APIKeys

# check if I can access Scopus API
try:
    s_sample = ScopusSearch(f"DOI (10.1021/acsnano.9b08494)").results[0]
    subscriber=True
except:
    subscriber=False

print(f"subscriber={subscriber}")
# Out:
# subscriber=True

# %% [markdown]
# * settings

# %%
pd.set_option("mode.chained_assignment", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Ready for retrieving

# %% [markdown]
# * **IMPORTANT: Retrieving Range**

# %%
# 확보 JCR 데이터 범위
YEAR_START = 2016
YEAR_END = 2021    # 포함

# 논문 평가 기준 년도
YEAR_REMARK = 2021

# %% [markdown]
# * JCR data load

# %%
dfs_JCR_SCIE = {}
data_JCR = "./data/JCR_SCIE_(2016-2021).xlsx"

for y in range(YEAR_START, YEAR_END+1):
    print(f"{y}년도 시트를 로딩중입니다.", end="\t")
    try:
        dfs_JCR_SCIE.update({str(y):pd.read_excel(data_JCR, sheet_name=f"JCR {y}")})
        print(f"# sheet name: JCR {y}")
    except ValueError as e:
        dfs_JCR_SCIE.update({str(y):pd.read_excel(data_JCR, sheet_name=f"JCR_SCIE_{y}+")})
        print(f"# sheet name: JCR_SCIE_{y}+")
# Out:
# 2017년도 시트를 로딩중입니다.	# sheet name: JCR 2017
# 2018년도 시트를 로딩중입니다.	# sheet name: JCR 2018
# 2019년도 시트를 로딩중입니다.	# sheet name: JCR 2019
# 2020년도 시트를 로딩중입니다.	# sheet name: JCR 2020
# 2021년도 시트를 로딩중입니다.	# sheet name: JCR_SCIE_2021+

# %% [markdown]
# * 확보한 JCR data에 2019, 2020년 기준으로 EISSN 데이터 추가

# %%
# EISSN 인가
for k in dfs_JCR_SCIE.keys():
    col_capitals = np.array([c.upper() for c in dfs_JCR_SCIE[k].columns])
    if "EISSN" in col_capitals:
        idx_eissn = np.where("EISSN" == col_capitals)[0][0]
        dfs_JCR_SCIE[k] = dfs_JCR_SCIE[k].rename(columns={dfs_JCR_SCIE[k].columns[idx_eissn]:"EISSN"})

EISSN_2019 = dfs_JCR_SCIE["2019"][["Title20", "ISO_ABBREV", "TITLE", "ISSN", "EISSN"]]
EISSN_REMARK = dfs_JCR_SCIE[f"{YEAR_REMARK}"][["Title20", "ISO_ABBREV", "TITLE", "ISSN", "EISSN"]]
EISSN = pd.concat([EISSN_2019, EISSN_REMARK], axis=0).drop_duplicates("ISSN")

for k in dfs_JCR_SCIE.keys():
    col_capitals = np.array([c.upper() for c in dfs_JCR_SCIE[k].columns])
    if "EISSN" not in col_capitals:
        dfs_JCR_SCIE[k] = dfs_JCR_SCIE[k].merge(EISSN, how="left", on=["Title20", "ISO_ABBREV", "TITLE", "ISSN"])

# %% [markdown]
# * natural language processor

# %%
def regularize_date_publication(_str):
    _str = _str.replace(",", "")
    token_date = _str.split(' ')
    if len(token_date) == 1: # year only
        year = _str
        s = _str
    elif (re.match('[0-9]', token_date[0])):
        day, month, year = token_date[0], token_date[1][:3].upper(), token_date[2]
        s = ' '.join([month, day, year])
        
    # 'August 26, 2021' -> 'AUG 26 2021'
    elif (re.match('[A-Za-z]', token_date[0]) and re.match('[0-9]', token_date[1]) and int(token_date[1])<32):    
        month, day, year = token_date[0][:3].upper(), token_date[1], token_date[2]
        s = ' '.join([month, day, year])
    else:
        month, year = token_date[0][:3].upper(), token_date[1]
        s = ' '.join([month, year])
        
    return (int(year), s)

def get_pub_index(_pub_name, _df):
    list_title = _df['TITLE'].map(regularize)
    pub_index = np.where(regularize(_pub_name) == list_title)[0]
    if len(pub_index) > 0:
        return pub_index
    else:
        return np.array([])

def get_pub_index_eissn(_pub_eissn, _df):
    list_eissn = _df['EISSN'].str.replace("-","").values
    pub_index = np.where(_pub_eissn == list_eissn)[0]
    if len(pub_index) > 0:
        return pub_index
    return np.array([])

def regularize(_str):
    return re.sub('[^A-Za-z0-9]+', '', re.sub('&', 'and', _str)).lower()       

def regularize_space(_str):
    return re.sub('[^A-Za-z0-9]+', ' ', re.sub('&', 'and', _str)).lower()

# %% [markdown]
# # Working on Applicants data

# %% [markdown]
# ## Scopus

# %% [markdown]
# * 지원자 데이터 불러오기

# %%
data_applicants = "./data/[연구직] 논문실적(기초데이터).xlsx"

df_applicants = pd.read_excel(data_applicants, header=1, dtype={"UT":str})

# display example
print(df_applicants.columns)
df_applicants.head(3)
print(df_applicants.shape)
# Out:
# Index(['전체순번', '지원번호 내 순번', '지원번호', '성명', '영문이름', '지원자 입력 영문명', '분야', 'DOI',
#        '논문명', 'SCIE구분', '저자순위', '저자구분', '게재구분', '저널명', '게재일', '출판사', 'ISSN',
#        '논문구분\n(SCIE)', 'Publication Date', '#citation',
#        'Publication Year journal impact factor',
#        '2021\njournal\nimpact\nfactor',
#        '2021 journal impact factor percentile', '1st Author',
#        '1ST AUTHOR\n(Y/N)', 'Reprint Author', 'REPRINT AUTHOR\n(Y/N)',
#        'Source\n(Journal)', 'volume', 'issue', 'Notes'],
#       dtype='object')
# (1222, 31)

# %% [markdown]
# * 논문 내 영문명 결측치를 영문명으로 메움

# %%
nonsign = "미작성"

idx_name_en_missing = np.where(df_applicants["지원자 입력 영문명"].isna())[0]
idx_name_en_missing = np.append(idx_name_en_missing, np.where(df_applicants["지원자 입력 영문명"]=="미작성")[0])
    
df_applicants["지원자 입력 영문명"].loc[idx_name_en_missing] = df_applicants["영문이름"].loc[idx_name_en_missing]

# %% [markdown]
# * paper data retrieve

# %%
# %%time

# 중도 중단시 재개 번호
start = 0
end = df_applicants.shape[0]

for i in range(start, end):
    
    # verbose: iteration
    if i%100 == 0 and i > 0:
        print(f"# working on {i}th article....")
    
    # 중도 중단 지점부터만 시작
    if i < start:
        continue     
    
    # 1 line DataFrame
    df = df_applicants.loc[i]
    
    # data extraction.
    doi = df["DOI"]
    print(f"{doi}")
    if isinstance(doi, str):
        doi = doi.lstrip("https://doi.org/")
    
    title = df["논문명"]
    no = df["전체순번"]
    
    ### article retrieval
    notes = []    # 
    s = ScopusSearch(f"DOI ({doi})", download=True, subscriber=subscriber).results
    if s == None:
        try:
            s = ScopusSearch(f"TITLE ({title})", download=True, subscriber=subscriber).results
            # DOI로는 검색 불가. title로 검색 성공
            if s != None:
                doi = s[0].doi
                notes.append(f"DOI 오류: {doi}")
            # DOI, title로 모두 검색 불가
            else:
                print(f"- 전체순번 {no} is invalid.")
                notes.append("Scopus에서 doi 및 title 검색 불가: 확인 필요")
                df_applicants["Notes"].loc[i] = "\n".join(notes)
                continue
        # Scopus에서 접근 자체가 불가
        except:
            print(f"- No.{i} is not accessible in Scopus.")
            notes.append("Scopus에서 접근 불가. 확인 필요")
            df_applicants["Notes"].loc[i] = "\n".join(notes)
            continue     
    
    info_scopus = s[0]
        
    ### SCIE 여부 (Y/N)
    # index of publication at JCR data
    index_remark = get_pub_index(info_scopus.publicationName, dfs_JCR_SCIE[str(YEAR_REMARK)])
    if len(index_remark) == 0: # publicationName으로 찾지 못하면 EISSN으로 검색
        index_remark = get_pub_index_eissn(info_scopus.eIssn, dfs_JCR_SCIE[str(YEAR_REMARK)])
    
    # decision
    if len(index_remark) > 0:
        df_applicants["논문구분\n(SCIE)"].loc[i] = "Y"
    else:
        df_applicants["논문구분\n(SCIE)"].loc[i] = "N"
        notes.append("JCR 목록에 없음")
        df_applicants["Notes"].loc[i] = "\n".join(notes)
        
    ### Publication Date
    year, date = regularize_date_publication(info_scopus.coverDisplayDate)
    df_applicants["Publication Date"].loc[i] = date
    df_applicants["#citation"].loc[i] = str(info_scopus.citedby_count)

    ### Impact Factor @Publication year and @remark year
    if year < YEAR_START:
        notes.append(f"{YEAR_START-1} 이전 논문")
        df_applicants["Notes"].loc[i] = "\n".join(notes)
    
    elif year <= YEAR_END:
        index_pub = get_pub_index(info_scopus.publicationName, dfs_JCR_SCIE[str(year)])
        if len(index_pub) > 0:
            index_pub = index_pub[0]
            jif_n = str(dfs_JCR_SCIE[str(year)]["IMPACT_FACTOR"][index_pub])
        else:
            index_pub = get_pub_index_eissn(info_scopus.eIssn, dfs_JCR_SCIE[str(year)])
            if len(index_pub) > 0:
                index_pub = index_pub[0]
                jif_n = str(dfs_JCR_SCIE[str(year)]["IMPACT_FACTOR"][index_pub])
            else:
                # JCR Data에 해당 publication이 없음
                notes.append(f"IF를 찾지 못함")
                df_applicants["Notes"].loc[i] = "\n".join(notes)
                jif_n = f"IF 미발급: JCR Data에 없음"

    else:
        jif_n = f"IF 미발급: {year}년 출판"
    
    df_applicants["Publication Year journal impact factor"].loc[i] = jif_n

    ### Impact Factor Percentile @remark year
    if index_remark.size > 0:
        df_applicants[f"{YEAR_REMARK}\njournal\nimpact\nfactor"].loc[i] = str(dfs_JCR_SCIE[f"{YEAR_REMARK}"]["IMPACT_FACTOR"][index_remark[0]])
        ifp = dfs_JCR_SCIE[str(YEAR_REMARK)].loc[index_remark, "JIF_PERCENTILE"]
        df_applicants[f"{YEAR_REMARK} journal impact factor percentile"].loc[i] = str(ifp.values[0])
    else:
        df_applicants[f"{YEAR_REMARK} journal impact factor percentile"].loc[i] = "mrnIF 없음"
    
    ### Author data
    # authors in paper
    if info_scopus.author_names:
        authors_raw = info_scopus.author_names.split(";")
        authors_reg = [regularize(n) for n in authors_raw]

        # applicants name
        name = df["영문이름"]
        name_paper = df["지원자 입력 영문명"]
        name_swap = ", ".join(name.split(" ")[1:] + name.split(" ")[:1]).rstrip(",")
        name_paper_swap = " ".join([name_paper.split(" ")[-1]] + name_paper.split(" ")[:-1])
        name_reg = regularize(df["영문이름"])
        name_paper_reg = regularize(df["지원자 입력 영문명"])
        name_swap_reg = regularize(", ".join(name[1:] + name[:1]))
        name_paper_swap_reg = regularize(name_paper_swap)

        # name matching. 우선순위대로
        if any([name_paper in a for a in authors_raw]):
            idx_author = [name_paper in a for a in authors_raw].index(True)
        elif any([name in a for a in authors_raw]):
            idx_author = [name in a for a in authors_raw].index(True)
        elif any([name_swap in a for a in authors_raw]):
            idx_author = [name_swap in a for a in authors_raw].index(True)
        elif any([name_paper_swap in a for a in authors_raw]):
            idx_author = [name_paper_swap in a for a in authors_raw].index(True)
        elif any([name_paper_reg in a for a in authors_reg]):
            idx_author = [name_paper_reg in a for a in authors_reg].index(True)
        elif any([name_reg in a for a in authors_reg]):
            idx_author = [name_reg in a for a in authors_reg].index(True)
        elif any([name_swap_reg in a for a in authors_reg]):
            idx_author = [name_swap_reg in a for a in authors_reg].index(True)
        elif any([name_paper_swap_reg in a for a in authors_reg]):
            idx_author = [name_paper_swap_reg in a for a in authors_reg].index(True)
        else:    # 이니셜로만 되어 있는 것은 아닌지 확인
            if "," in name:  # 이름에 ","가 있는 경우 : "성, 이름"으로 구성되어 있는 것으로 가정
                familyname, givenname = name.split(",")[0].lower(), name.split(",")[1].lstrip(" ").lower()
            else:            # 이름에 ","가 없는 경우 : "이름 성"으로 구성되어 있는 것으로 가정.
                familyname, givenname = name.split(" ")[-1].lower(), "".join(name.split(" ")[:-1]).lower()

            name_TF = [True if ((n[0] == familyname and len(set(n[1:])-set(givenname))==0) or 
                                (n[-1]== familyname and len(set(n[:-1])-set(givenname))==0)) 
                       else False 
                       for n in authors_reg]
            name_scopus_err_reg = regularize(" ".join([*givenname.split(" ")[1:], familyname, givenname.split(" ")[0]]))

            if len(np.where(np.array(name_TF)==True)[0]) > 0:
                idx_author = np.where(np.array(name_TF)==True)[0][0]
                notes.append("확인 필요: 논문 저자 이름이 약어로 표현됨. 확인 필요.")

            # Lim, Suk Hyun이 Scopus DB에 Hyun Lim, Suk으로 입력된 사례: 10.1016/j.fuel.2021.122481
            elif name_scopus_err_reg in authors_reg:
                idx_author = authors_reg.index(name_scopus_err_reg)
                notes.append("확인 필요: ScopusDB에 이름이 한 글자씩 밀려서 잘못 입력된 듯함.")
            else:
                idx_author = None
                notes.append("확인 필요: 저자 명단에서 지원자를 찾지 못함.")

        # first author
        first_author = authors_raw[0]
        if idx_author == 0:
            first_author_yn = "Y"
        else:
            first_author_yn = "N"

        df_applicants["1st Author"].loc[i] = first_author
        df_applicants["1ST AUTHOR\n(Y/N)"].loc[i] = first_author_yn
    
    ### Publication
    df_applicants["Source\n(Journal)"].loc[i] = info_scopus.publicationName.upper()
    df_applicants["volume"].loc[i] = info_scopus.volume
    
    if info_scopus.issueIdentifier != None:
        issue = info_scopus.issueIdentifier
    else:
        issue = ''
    df_applicants["issue"].loc[i] = issue
    
    # write in every step
    df_applicants["Notes"].loc[i] = "\n".join(notes)
    df_applicants.to_excel(f"applicants_fill_from{start}_to{end}.xlsx", index=False)
# Out:
# 10.1039/C9TA11854C
# 10.1021/acsami.2c01216
# 10.1016/j.jpowsour.2020.227903
# 10.1016/j.jpowsour.2020.228810
# 10.1039/C8NR02903B
# 10.1021/acsaem.1c00826
# 10.1016/j.jqsrt.2022.108165
# 10.1021/acsami.9b16742
# 10.1063/5.0017838
# 10.1016/j.jqsrt.2020.107475
# 10.1038/s41598-019-51407-2
# 10.1016/j.applthermaleng.2022.118771
# 10.1038/s41598-020-65811-6
# 10.1016/j.enconman.2022.116046
# 10.1016/j.applthermaleng.2022.118744
# 10.1016/j.enbuild.2021.110921
# 10.3390/en14206688
# 10.1016/j.ijheatmasstransfer.2020.119408
# 10.7849/ksnre.2021.2022
# - 전체순번 1205 is invalid.
# 10.7836/kses.2021.41.1.013
# - 전체순번 1206 is invalid.
# 10.1016/j.jcou.2020.101242
# 10.1016/j.apsusc.2020.146651
# 10.1021/acsaem.0c01407
# 10.1021/acsaem.9b01874
# 10.1038/s41598-018-36759-5
# 10.1016/j.snb.2018.09.048
# 10.1016/j.scriptamat.2018.08.015
# 10.1002/cplu.201800139
# 10.1016/j.snb.2017.09.096
# 10.33961/jecst.2019.00199
# 10.1016/j.nanoen.2018.12.039
# 10.1246/bcsj.20180174
# 10.1016/j.jallcom.2022.163956
# 10.1016/j.jpowsour.2022.231039
# 10.1016/j.ceramint.2017.12.007
# 10.1016/j.jiec.2018.07.045
# 10.1016/j.apcatb.2020.118887
# 10.1016/j.cej.2022.134621
# 10.1007/s11814-020-0709-9
# 10.3390/catal10040461
# 10.1016/j.jcou.2021.101713
# 10.1016/j.ijheatmasstransfer.2022.123576
# 10.1016/j.ijheatmasstransfer.2021.121576
# 10.1016/j.ijheatmasstransfer.2019.05.092
# 10.3795/KSME-B.2019.43.4.297
# https://doi.org/10.1016/j.chempr.2022.03.023
# https://doi.org/10.1039/D1CC04858A
# https://doi.org/10.1016/j.micromeso.2020.110153
# https://doi.org/10.1002/anie.201809762
# 10.1016/j.jechem.2021.08.027
# 10.1016/j.rser.2020.110524
# 10.1039/D2GC01786E
# 10.1016/j.jcou.2022.102228
# 10.1016/j.enconman.2022.115606
# 10.1016/j.applthermaleng.2021.117803
# 10.1016/j.energy.2019.02.013
# 10.1016/j.jclepro.2022.130597
# 10.1016/j.energy.2018.10.185
# 10.1016/j.jcou.2021.101753
# 10.1016/j.cej.2021.129678
# 10.1039/d0ta04721j
# 10.1016/j.jmst.2021.05.084
# 10.1016/j.jmst.2020.02.054
# 10.1016/j.jpowsour.2021.230481
# 10.1021/acsami.0c11047
# 10.1021/acssuschemeng.9b03776
# 10.1021/acssuschemeng.9b02044
# 10.1039/C9QI00557A
# 10.1016/j.jallcom.2020.156512
# 10.1016/j.cej.2020.127158
# 10.1016/j.cej.2019.122315
# 10.1016/j.jhazmat.2021.127262
# 10.1016/j.jclepro.2022.134022
# 10.1016/j.apsusc.2022.153930
# 10.1016/j.jhazmat.2021.125043
# 10.1021/jacs.2c02362
# 10.1021/acs.jpclett.9b00921
# 10.1016/j.apsusc.2022.155155
# 10.1016/j.apsusc.2022.155005
# 10.1016/j.elecom.2022.107375
# 10.1063/1.5081066
# 10.1107/S160057751901676X
# 10.3938/jkps.75.541
# 10.1039/D1TC03436G
# 10.1016/j.joule.2022.04.007
# 10.1021/acsenergylett.0c01022
# 10.1002/aenm.202100555
# 10.1039/d1ee00984b
# 10.1002/aenm.201901787
# 10.1002/aenm.201901204
# 10.1002/advs.202004092
# 10.1002/aenm.202203012
# 10.1002/aenm.202203198
# 10.1007/s40684-022-00485-1
# 10.1021/acsenergylett.2c00974
# - 전체순번 1122 is invalid.
# 10.1039/D0TA03774E
# 10.1002/cctc.201900184
# 10.1149/1945-7111/ac6e8c
# 10.1016/j.nanoen.2022.107446
# 10.1021/acsami.1c07452
# # working on 100th article....
# 10.1039/D0CC02871A
# 10.1021/acs.organomet.1c00372
# 10.1016/j.jhazmat.2021.125904
# 10.1016/j.jcou.2022.101981
# 10.1016/j.cej.2022.135612
# 10.1021/acs.chemmater.0c03423
# 10.1021/acssuschemeng.1c03429
# 10.1021/acs.chemmater.2c00846
# 10.1038/s41598-019-43098-6
# 10.1039/D1RA07408C
# 10.1016/j.nanoen.2019.104034
# 10.1002/app.49156
# 10.1038/s41598-022-05738-2
# 10.1016/j.egyr.2022.05.288
# 10.1039/C7TA09953C
# 10.1039/C9TA03934A
# 10.1021/acs.accounts.1c00682
# 10.1002/bkcs.12270
# 10.1016/j.matt.2019.03.004
# 10.1002/anie.202202923
# 10.1016/j.fuel.2020.117445
# 10.1016/j.fuel.2019.116045
# 10.1080/02786826.2022.2100241
# 10.3390/toxics10100616
# 10.4209/aaqr.2018.10.0367
# 10.4209/aaqr.210378
# 10.4209/aaqr.2020.03.0117
# 10.1111/ina.13173
# 10.3390/toxics10100609
# 10.4209/aaqr.210383
# 10.1016/j.apsusc.2018.12.142
# 10.1016/j.jallcom.2022.166078
# 10.1016/j.ceramint.2020.12.263
# 10.1016/j.ceramint.2018.11.050
# 10.1002/ente.201700777
# 10.1016/j.ceramint.2019.09.143
# 10.1021/acscatal.0c04526
# 10.1039/C7TA10678E
# 10.1016/j.apsusc.2020.148105
# 10.1021/acsami.9b10572
# 10.1016/j.jallcom.2021.163407
# 10.1016/j.jallcom.2022.166332
# 10.1016/j.cej.2021.131063
# 10.1002/adma.201907006
# 10.1016/j.fuel.2022.124108
# 10.1016/j.jallcom.2018.05.059
# 10.1088/1361-6528/aaae3e
# 10.1016/j.apsusc.2017.06.259
# 10.1002/adma.201904524
# 10.1021/acssuschemeng.9b00584
# 10.1016/j.ensm.2019.05.017
# 10.14478/ace.2020.1077
# 10.1021/acsomega.8b01371
# 10.1063/5.0040808
# 10.1039/c9ta04220b
# 10.1016/j.mtphys.2020.100309
# 10.1016/j.actamat.2021.117443
# 10.1016/j.jallcom.2020.157145
# 10.3390/ma15041272
# 10.3390/ma14226774
# 10.3390/app112311341
# 10.3938/jkps.72.95
# 10.1016/j.apcatb.2020.119059
# 10.1016/j.chemosphere.2020.126133
# 10.1016/j.micromeso.2021.110985
# 10.1007/s11814-020-0730-z
# 10.1016/j.apcatb.2019.03.076
# 10.1021/acsami.8b07130
# 10.1016/j.cej.2019.122133
# 10.1016/j.chemosphere.2020.129161
# 10.1016/j.jhazmat.2020.124202
# 10.1016/j.apsusc.2022.154290
# 10.1016/j.matlet.2020.128387
# 10.1016/j.micromeso.2020.110432
# 10.1016/j.fuproc.2020.106469
# 10.1016/j.cattod.2019.09.004
# 10.1016/j.micromeso.2020.110011
# 10.1016/j.micromeso.2019.109979
# 10.1016/j.jiec.2019.09.028
# 10.1016/j.mcat.2019.110395
# 10.1021/acsami.9b00546
# 10.1021/acs.iecr.8b05220
# 10.1016/j.micromeso.2017.09.006
# 10.3390/su13063092
# 10.3390/su12093582
# 10.22712/susb.20200007
# 10.12813/kieae.2020.20.3.039
# - 전체순번 1038 is invalid.
# 10.5659/JAIK.2020.36.6.169
# 10.1016/j.enbuild.2022.112124
# 10.1016/j.buildenv.2021.108061
# 10.1016/j.applthermaleng.2021.116655
# 10.1016/j.enbuild.2021.110765
# 10.1016/j.enbuild.2019.03.051
# 10.1016/j.enconman.2022.115699
# 10.1016/j.enconman.2022.115384
# 10.1016/j.ijrefrig.2020.10.032
# 10.1016/j.enconman.2019.112128
# 10.1021/acsnano.8b02040
# 10.1016/j.biomaterials.2021.120948
# 10.3390/nano11061446
# # working on 200th article....
# 10.1021/acsami.1c09245
# 10.1021/acsami.1c20889
# 10.1038/s41598-019-38552-4
# 10.1002/ente.201700642
# 10.1252/JCEJ.19WE078
# 10.1039/c8ra07586g
# 10.1021/acsabm.2c00247
# 10.1149/2.0061904jes
# 10.1016/j.apsusc.2020.145389
# 10.1002/bkcs.12297
# 10.1039/d1ra02193a
# 10.1021/acsomega.1c06720
# 10.1016/j.ijhydene.2022.10.174
# 10.1016/j.molliq.2021.117612
# 10.1039/d0ce00202j
# 10.1016/j.chemosphere.2022.136166
# 10.1039/d0ra04744a
# 10.1016/j.enbuild.2019.06.012
# 10.1016/j.enbuild.2020.110293
# 10.1016/j.enbuild.2021.111059
# 10.3390/su14106000
# 10.5659/JAIK.2021.37.11.247
# 10.5659/JAIK_SC.2020.36.5.177
# - 전체순번 1005 is invalid.
# 10.1115/1.4055541
# 10.1038/s41598-022-19530-9
# 10.3390/en13215831
# 10.3390/pr9091595
# 10.1080/19942060.2022.2074544
# 10.1115/1.4053956
# 10.1177/0954406220973055
# 10.1177/1687814020914790
# 10.1007/s12206-019-0628-z
# 10.1080/19942060.2019.1643408
# 10.1039/d2nj03401h
# 10.1002/celc.202200233
# 10.1016/j.cej.2021.131339
# 10.1016/j.jiec.2021.11.056
# 10.1016/j.jpowsour.2022.231107
# 10.1016/j.cej.2019.04.151
# 10.1021/acsami.7b14599
# 10.1002/ente.202000184
# 10.1002/celc.201900543
# 10.1021/acssuschemeng.8b05603
# 10.1038/s41467-022-29783-7
# 10.1002/smll.202105087
# 10.1039/d0ta01869d
# 10.1016/j.watres.2018.08.033
# 10.1016/j.carbon.2017.10.073
# 10.1016/j.jpowsour.2021.230953
# 10.1021/acssuschemeng.8b03383
# 10.1016/j.ijhydene.2018.08.124
# 10.1039/d0cc04752j
# 10.1016/j.elecom.2022.107301
# 10.1016/j.apcatb.2021.120884
# 10.1038/s41467-022-28260-5
# 10.1039/d1ee03861c
# 10.1002/adsu.202100216
# 10.1016/j.apcatb.2021.120205
# 10.1038/s41467-021-24578-8
# 10.1039/d1ta03182a
# 10.1021/acs.est.0c04262
# 10.1016/j.nanoen.2020.105030
# 10.1039/ c9ew01144g
# 10.1016/j.checat.2022.07.016
# 10.1038/s41467-022-33236-6
# 10.1002/anie.202202923
# 10.1039/D0TA09310F
# 10.1016/j.surfin.2021.101533
# 10.1016/j.jece.2021.105216
# 10.1016/j.chemosphere.2020.128943
# 10.1016/j.jhazmat.2019.121274
# 10.4491/KSEE.2018.40.5.203
# - 전체순번 950 is invalid.
# 10.1039/d0ra09017d
# 10.1016/j.cej.2021.128536
# 10.1039/d1ra00181g
# 10.1016/j.chemosphere.2021.129789
# 10.1038/s41598-020-61930-2
# 10.1109/TPEL.2021.3127010
# 10.1109/TPEL.2020.3016684
# 10.1109/TPEL.2022.3165182
# 10.3390/en14071889
# 10.6113/TKPE.2021.26.4.277
# - 전체순번 945 is invalid.
# 10.1038/s41598-022-18910-5
# 10.1021/acs.nanolett.1c04117
# 10.1038/s41427-019-0187-x
# 10.1038/s41535-021-00361-2
# - 전체순번 934 is invalid.
# 10.1103/PhysRevB.106.134310
# 10.1063/5.0076160
# 10.1038/s41467-022-32826-8
# 10.1126/sciadv.abb8553
# 10.1103/PhysRevMaterials.2.084412
# 10.1063/1.5127355
# 10.1016/j.mcat.2017.06.012
# 10.3390/catal12050559
# 10.1016/j.apt.2017.07.002
# 10.3390/catal12101279
# 10.1007/s11164-018-3382-4
# 10.7467/KSAE.2020.28.4.271
# 10.1111/jace.18722
# 10.3390/ma15030719
# # working on 300th article....
# 10.1007/s42860-022-00172-x
# 10.1002/celc.202101594
# 10.1016/j.jallcom.2022.164282
# 10.1111/jace.16466
# 10.3365/KJMM.2019.57.2.108
# 10.3365/KJMM.2019.57.6.374
# 10.1016/j.net.2019.04.022
# 10.3390/en14185846
# 10.5762/KAIS.2020.21.11.892
# - 전체순번 915 is invalid.
# 10.5407/JKSV.2018.16.1.037
# - 전체순번 916 is invalid.
# 10.1016/j.mser.2021.100660
# 10.1002/adfm.202108026
# 10.1039/D0TA09354H
# 10.1021/acsami.9b22933
# 10.1021/acsami.0c11384
# 10.1016/j.carbon.2022.12.025
# 10.1039/c8tc01852a
# 10.1063/1.5001237
# 10.1039/D0TA09354H
# 10.1016/j.cej.2022.139500
# 10.1016/j.jcat.2019.09.004
# 10.1016/j.matdes.2020.108497
# 10.1039/d0dt01228a
# 10.1039/d0re00148a
# 10.1016/j.jiec.2021.07.012
# 10.1246/cl.180005
# 10.1007/s10562-021-03641-5
# 10.1007/s12274-019-2487-4
# 10.1039/D0MA00920B
# - 전체순번 897 is invalid.
# 10.1039/d1nj00586c
# 10.1016/j.jiec.2021.11.018
# /10.5855/ENERGY.2022.31.2.098
# - 전체순번 900 is invalid.
# 10.3938/PhiT.28.029
# - 전체순번 901 is invalid.
# 10.1039/D2TA08442B
# - 전체순번 902 is invalid.
# 10.1016/j.cej.2022.135388
# 10.1021/acsenergylett.1c02130
# 10.1016/j.chemosphere.2020.129166
# 10.1016/j.electacta.2021.137900
# 10.1016/j.cej.2020.126410
# 10.1149/1945-7111/ab6a80
# 10.1016/j.cattod.2018.12.014
# 10.1016/j.cej.2018.09.192
# 10.1039/c8cy00685g
# 10.1016/j.apcatb.2017.12.043
# 10.1016/j.actamat.2020.116563
# 10.1021/acscatal.9b00451
# 10.1038/s41524-021-00605-6
# 10.1039/d0lc00461h
# 10.1007/s11814-019-0337-4
# 10.1007/s11814-018-0164-z
# 10.1109/TIE.2017.2740835
# 10.1109/TIE.2021.3084162
# 10.3390/electronics9111841
# 10.1109/TIE.2017.2752127
# 10.1021/jacs.0c08997
# 10.1002/adom.202002135
# 10.1039/D1TC01702K
# 10.1039/D1TC05090G
# 10.1021/acsmaterialslett.2c00866
# 10.1021/acs.jctc.0c00138
# 10.1063/5.0028227
# 10.1002/adma.202208190
# 10.1126/science.abo2757
# 10.1021/acsmaterialslett.2c00619
# 10.1002/adma.202102091
# 10.1007/s40192-022-00250-x
# 10.1038/s41524-021-00564-y
# 10.1002/smll.201801529
# 10.1021/acsanm.2c03323
# 10.1039/C9RA05929F
# 10.1039/C9NR06407A
# 10.1016/j.apsusc.2021.150201
# 10.1039/C8RA03306D
# 10.1039/D1CP04450H
# 10.1021/jacs.2c04741
# 10.1021/acs.jpca.0c07802
# 10.1016/j.nanoen.2019.05.017
# 10.1186/s40543-020-00216-8
# 10.1016/j.jallcom.2019.06.171
# 10.1021/acsami.0c09285
# 10.1021/acsami.9b03508
# 10.1002/smtd.202100558
# 10.1021/acsami.1c09725
# 10.1016/j.apsusc.2021.149852
# 10.1021/acs.jpclett.9b03328
# 10.1002/pip.3338
# 10.1038/s41598-020-66801-4
# 10.3390/en13071803
# 10.1016/j.cap.2018.09.004
# 10.1016/j.solmat.2020.110519
# 10.3938/jkps.76.774
# 10.1166/jno.2018.2406
# - 전체순번 836 is invalid.
# 10.1038/s41598-022-18910-5
# 10.3390/catal9060524
# 10.1016/j.cattod.2018.09.008
# 10.1007/s11814-018-0186-6
# 10.3390/en14248414
# 10.1007/s11164-018-3382-4
# 10.3390/ma15186356
# 10.1016/j.matchemphys.2019.03.035
# # working on 400th article....
# 10.1002/cctc.201901312
# 10.1109/TPEL.2018.2818441
# 10.1109/TPEL.2021.3102151
# 10.1016/j.enbuild.2021.111394
# 10.1016/j.apenergy.2018.04.086
# 10.1016/j.egyr.2022.04.034
# 10.3390/app8091645
# 10.3390/en12193777
# 10.3390/en14040836
# 10.3390/su14010481
# 10.3390/cli9010017
# 10.1016/j.enbuild.2019.07.031
# 10.1002/ese3.1040
# 10.1016/j.enbuild.2019.07.031
# 10.1115/1.4052858
# 10.1016/j.solener.2016.07.056
# 10.7836/kses.2021.41.5.025
# - 전체순번 814 is invalid.
# 10.7836/kses.2022.42.5.001
# - 전체순번 815 is invalid.
# 10.7836/kses.2021.41.4.147
# - 전체순번 816 is invalid.
# 10.7836/kses.2020.40.5.001
# - 전체순번 817 is invalid.
# 10.7836/kses.2022.42.1.127
# - 전체순번 818 is invalid.
# 10.7836/kses.2021.41.3.011
# - 전체순번 819 is invalid.
# 10.1016/j.enbuild.2020.110629
# 10.1016/j.scs.2021.103049
# 10.3390/su13126649
# 10.3390/buildings12010029
# 10.5659/JAIK_SC.2020.36.3.147
# - 전체순번 796 is invalid.
# 10.5659/JAIK.2021.37.4.241
# 10.5659/JAIK_SC.2019.35.10.225
# - 전체순번 798 is invalid.
# 10.6106/KJCEM.2018.19.2.038
# - No.429 is not accessible in Scopus.
# 10.5659/JAIK_SC.2020.36.2.165
# - 전체순번 800 is invalid.
# 10.1016/j.jcat.2018.10.013
# 10.1016/j.jcat.2019.09.040
# 10.1016/j.apcata.2020.117837
# 10.1016/j.jcat.2018.05.002
# 10.1016/j.fuel.2018.02.154
# 10.1016/j.fuel.2019.116620
# 10.1016/j.jcat.2020.07.009
# 10.1021/acs.chemmater.2c00846
# 10.3390/catal11111272
# 10.1016/j.jiec.2022.02.023
# 10.1002/anie.202209659
# 10.1039/C9TA00464E
# 10.1039/D1TA04782E
# 10.1039/C8TA06744A
# 10.1021/acsami.8b18300
# 10.1021/acsami.7b19119
# 10.1021/acssuschemeng.0c05290
# 10.1039/D1NR05052D
# 10.1021/acsaem.2c02701
# 10.1002/admi.201800628
# 10.1016/j.isci.2022.105768
# 10.1063/1.5060638
# 10.1109/JSEN.2021.3125691
# 10.1063/1.5140618
# 10.1016/j.applthermaleng.2021.116825
# 10.1016/j.applthermaleng.2020.116104
# 10.1016/j.ijrefrig.2017.10.029
# 10.5109/4055215
# 10.1016/j.nanoen.2020.105703
# 10.1021/acsnano.0c05476
# 10.1021/acsami.0c08128
# 10.1002/adom.201901932
# 10.1002/adfm.202208792
# 10.1016/j.nanoen.2020.104749
# 10.1021/acsnano.9b09082
# 10.1021/acsami.8b19848
# 10.1021/acsami.0c08977
# 10.1021/acsami.0c00143
# 10.1038/s41598-020-63695-0.
# 10.1016/j.compchemeng.2020.107133
# 10.1016/j.arcontrol.2021.10.006
# 10.1016/j.jprocont.2022.05.004
# 10.1016/j.compchemeng.2019.02.015
# 10.1016/j.jprocont.2020.02.003
# 10.1016/j.jcou.2018.04.022
# 10.1016/j.ifacol.2021.08.289
# 10.1016/j.ifacol.2018.11.115
# 10.23919/ICCAS.2017.8204225
# 10.1039/D1TA00507C
# 10.1039/C9TA04818A
# 10.1039/C8TA01660G
# 10.1016/j.jpowsour.2022.232290
# 10.1016/j.snb.2022.132236
# 10.1016/j.snb.2020.128930
# 10.1007/s40684-020-00290-8
# 10.3389/fchem.2022.873758
# - 전체순번 741 is invalid.
# 10.1039/D1EE01497H
# 10.1016/j.jpowsour.2020.228606
# 10.1007/s40820-022-00795-8
# 10.1002/advs.201800727
# 10.1039/d2ce00585a
# 10.1007/s40843-022-2111-2
# 10.4191/kcers.2018.55.3.08
# 10.1016/j.apcatb.2021.120217
# 10.1021/acsami.9b03712
# 10.1002/smll.202105611
# 10.1021/acsami.9b09344
# 10.1021/acscatal.8b01999
# 10.1002/smtd.202000755
# # working on 500th article....
# 10.1039/C8CY00685G
# 10.1186/s40580-022-00323-9
# 10.1007/s13391-022-00346-8
# 10.1002/sstr.202200236
# - 전체순번 731 is invalid.
# 10.1039/c8ta03858a
# https://doi.org/10.1016/j.snb.2019.02.009
# 10.1002/smtd.202100239
# 10.1002/adfm.202009241
# 10.1016/j.apcatb.2022.122172
# 10.1021/acscatal.1c03879
# 10.1016/j.nanoen.2022.107206
# 10.1021/acsami.9b22615
# 10.1016/j.apsusc.2021.150254
# 10.1016/j.jiec.2022.04.011
# 10.1002/adfm.202113057
# 10.1002/advs.202104145
# 10.1021/acsaem.0c02217
# 10.1002/adfm.201905511
# 10.1016/j.jiec.2018.11.031
# 10.1166/jnn.2018.14902
# - No.519 is not accessible in Scopus.
# 10.1002/aenm.202103698
# 10.1002/adfm.202208001
# 10.1021/acsenergylett.0c00564
# 10.1016/j.apcatb.2022.121237
# 10.1039/d1ta01362a
# 10.1039/c8ta00479j
# 10.1021/acsami.0c16854
# 10.1002/solr.202100326
# 10.1021/acsaem.0c01097
# 10.1021/acs.jpcc.8b05184
# 10.1016/j.nanoen.2021.105924
# 10.1039/c8ta03343a
# 10.1021/acsami.7b18152
# 10.1021/acsami.8b20884
# 10.1039/d0nr00816h
# 10.1002/admt.202000174
# 10.1016/j.dyepig.2017.09.009
# 10.1021/acs.jpcc.1c07641
# 10.1039/c8ra08317g
# 10.1021/acsenergylett.2c02018
# 10.1002/anie.202102887
# 10.1021/acsenergylett.9b02511
# 10.1063/5.0057470
# 10.1016/j.buildenv.2022.109060
# 10.1016/j.buildenv.2021.108492
# 10.1016/j.buildenv.2021.107744
# 10.1016/j.buildenv.2022.109877
# 10.1080/19401493.2022.2075939
# 10.1016/j.aap.2021.106539
# 10.3390/s22093451
# 10.3390/su13042198
# 10.1016/j.buildenv.2018.01.043
# 10.1021/acs.energyfuels.2c01933
# 10.1039/D1TA02644E
# 10.1016/j.cattod.2018.11.048
# 10.1038/s41467-019-10034-1
# 10.1039/D1EE03014K
# 10.1039/D1EE01342D
# 10.1002/aenm.201800572
# 10.1021/acsenergylett.1c02430
# 10.1016/j.apsusc.2019.144160
# 10.1021/acssuschemeng.9b06797
# 10.1002/adom.201800577
# 10.1021/acscatal.0c01783
# 10.1016/j.apsusc.2022.155636
# 10.1016/j.solmat.2019.110197
# 10.1021/acs.jpclett.1c00335
# 10.1109/TNSRE.2017.2755667
# 10.3390/s21175926
# 10.1021/jacs.2c10507
# 10.1021/acscatal.0c02018
# 10.1039/d1qi01132d
# 10.1021/acs.organomet.9b00469
# 10.1021/acscatal.1c04281
# 10.1021/acscatal.0c00802
# 10.3390/catal10070758
# 10.1002/advs.202100332
# 10.1016/j.chempr.2021.11.024
# 10.1021/acscatal.1c04214
# 10.1016/j.cej.2022.141030
# - 전체순번 629 is invalid.
# 10.1016/j.apcatb.2018.12.077
# 10.1021/acs.jpcc.2c03662
# 10.1016/j.catcom.2022.106549
# 10.1039/C9EE03492G
# 10.1021/acsanm.0c02456
# 10.1021/jacs.9b01882
# 10.1038/s41467-018-07050-y
# 10.1021/acscatal.2c00947
# 10.1039/D0EE01308K
# 10.1002/cctc.201900934
# 10.1038/s41565-019-0367-4
# 10.1039/C7CE02235B
# 10.1039/C8TA01939H
# 10.1021/acs.jpcc.9b04620
# 10.1002/cnma.201900201
# 10.1016/j.cej.2022.140611
# 10.1016/j.jece.2022.108058
# 10.1016/j.ijhydene.2018.08.100
# 10.1016/j.cattod.2019.11.013
# 10.1016/j.apcata.2020.117694
# # working on 600th article....
# 10.3390/catal12121500
# - 전체순번 626 is invalid.
# 10.1016/j.ijheatfluidflow.2022.109032
# 10.1063/5.0095886
# 10.1007/s10494-022-00330-0
# 10.1016/j.combustflame.2022.112121
# 10.1016/j.combustflame.2021.111486
# 10.2514/1.J056707
# 10.1016/j.ast.2018.03.006
# 10.20910/JASE.2018.12.5.40
# - 전체순번 621 is invalid.
# 10.1016/j.apcatb.2022.121603
# 10.1038/s41377-022-00904-7
# 10.1016/j.cej.2021.130970
# 10.1016/j.ce10.1016/j.cej.2022.137045
# - No.612 is not accessible in Scopus.
# 10.1016/j.rser.2021.110849
# 10.1016/j.cej.2021.128486
# 10.1016/j.cej.2022.134790
# 10.1002/smll.202204309
# 10.1016/j.jhazmat.2021.126269
# 10.1016/j.jhazmat.2020.124412
# 10.1016/j.jhazmat.2021.125245
# 10.1016/j.jhazmat.2021.126648
# 10.1016/j.jhazmat.2020.123868
# 10.1016/j.cossms.2020.100805
# 10.1016/j.envpol.2020.115247
# 10.1016/j.bios.2021.113766
# 10.1016/j.envpol.2020.116174
# 10.1016/j.fuel.2022.123915
# 10.1016/j.ultsonch.2020.104960
# 10.1016/j.jallcom.2021.163446
# 10.1016/j.jallcom.2021.163446
# 10.1016/j.chemosphere.2021.131218
# 10.1016/j.envres.2021.111080
# 10.1016/j.chemosphere.2020.128358
# 10.1016/j.jallcom.2021.162011
# 10.1016/j.apsusc.2019.143665
# 10.1016/j.apsusc.2019.145006
# 10.1016/j.ceramint.2020.10.098
# 10.1016/j.ceramint.2020.02.270
# 10.1002/er.7721
# 10.1016/j.matlet.2021.131218
# 10.1016/j.chemosphere.2020.128262
# 10.3390/catal8090390
# 10.1016/j.chemosphere.2021.129782
# 10.1016/j.jmst.2022.09.043
# 10.1016/j.envpol.2021.118158
# 10.1016/j.jhazmat.2021.126585
# 10.1016/j.envpol.2021.116990
# 10.1038/s41598-021-93768-7
# 10.1016/j.jhazmat.2020.124980
# 10.1016/j.envres.2021.110741
# 10.3390/nano10112195
# 10.3390/nano10112195
# 10.3390/nano10020392
# 10.1007/s42835-022-01334-6
# 10.1007/s42835-021-00746-0
# 10.5370/JEET.2018.13.3.1398
# 10.1016/j.jiec.2022.11.050
# - 전체순번 557 is invalid.
# 10.1016/j.cattod.2022.09.016
# - 전체순번 558 is invalid.
# 10.1007/s11814-022-1182-4
# 10.1016/jcej.2022.135166
# 10.1016/j.jiec.2022.01.023
# 10.1016/j.ijbiomac.2021.01.108
# 10.1016/j.ijhydene.2020.06.114
# 10.1016/j.catcom.2019.105764
# 10.1016/j.cherd.2018.11.016
# 10.3390/catal10070766
# 10.1016/j.cej.2022.139973
# 10.1039/d2ta02031a
# 10.1039/d1na00384d
# 10.1021/acssuschemeng.1c03285
# 10.1021/acssuschemeng.0c03191
# 10.1021/acsami.8b13415
# 10.1002/adfm.202102741
# 10.1021/acssuschemeng.0c05192
# 10.1007/s12274-020-3187-9
# 10.1002/adma.202000936
# 10.1002/adfm.202001760
# 10.1088/2053-1583/ab2c32
# 10.1016/j.carbon.2018.11.027
# 10.1088/2053-1583/aae21f
# 10.1016/j.carbon.2018.06.071
# 10.1021/acs.jpcc.8b03329
# 10.1016/j.seppur.2020.117204
# 10.1016/j.powtec.2018.12.041
# 10.1016/j.cej.2019.122454
# 10.1016/j.cep.2020.107856
# 10.1016/j.powtec.2021.05.089
# 10.1007/s11814-019-0339-2
# 10.1007/s10163-019-00834-4
# 10.1007/s11814-018-0137-2
# 10.3390/atmos10020100
# 10.1021/acsnano.1c02408
# 10.1039/D0TA00179A
# 10.1002/aenm.201901987
# 10.1016/j.mee.2019.111082
# 10.1016/j.solmat.2019.110033
# 10.1016/j.nanoen.2019.04.072
# 10.1016/j.apcatb.2018.03.071
# 10.1016/j.apcatb.2020.119049
# 10.1039/d1ta10345h
# # working on 700th article....
# 10.1021/acsami.1c19224
# 10.1016/j.joule.2020.03.013
# 10.3390/catal9030224
# 10.1021/acsenergylett.9b02511
# 10.1021/acscatal.1c04581
# 10.1021/acsaem.0c02284
# 10.1021/acssuschemeng.0c08632
# 10.1016/j.jcat.2013.02.015
# 10.1021/jp309277n
# 10.1021/cs100160g
# 10.1016/j.jcat.2009.11.009
# 10.5012/bkcs.2008.29.2.413
# 10.1126/science.1204452
# 10.1038/nature08288
# 10.1016/j.jcat.2008.01.006
# 10.1021/cs300678n
# 10.1016/j.jcat.2009.03.014
# 10.1021/cs500034d
# 10.1016/j.fuel.2012.01.075
# 10.1016/j.apcatb.2010.01.015
# 10.1021/jp907015j
# 10.1039/B716735K
# 10.1166/jnn.2010.1537
# 10.1166/jnn.2011.4373
# 10.1166/jnn.2012.6412
# 10.1021/acsaem.1c03887
# 10.1002/smtd.202101236
# 10.1002/asia.202100810
# 10.1021/acsnano.0c09905
# 10.1039/D1TA01587G
# 10.1039/D1CP00236H
# 10.1039/D0TA11606H
# 10.1016/j.xcrp.2020.100260
# 10.1002/adma.202002210
# 10.1002/aenm.202002049
# 10.1039/D0NR04622A
# 10.1039/C9NR05750A
# 10.1039/C8CS00336J
# 10.4209/aaqr.2017.11.0471
# 10.1007/s42791-019-00022-3
# - 전체순번 479 is invalid.
# 10.4209/aaqr.2017.08.0263
# 10.1016/j.sna.2018.09.060
# 10.1039/c9lc00035f
# 10.1039/c8lc00429c
# 10.5194/amt-12-5335-2019
# 10.1109/TIE.2018.2818654
# 10.1109/JESTPE.2021.3079330
# 10.1109/TDEI.2018.007724
# 10.1109/TPS.2019.2909639
# 10.1109/TPS.2020.3034724
# 10.1109/TDEI.2018.007726
# 10.1109/TPS.2018.2842200
# 10.1109/TPS.2018.2829494
# 10.1109/TDEI.2019.007696
# 10.6113/TKPE.2019.24.4.268
# - 전체순번 474 is invalid.
# 10.6113/TKPE.2021.26.1.32
# - 전체순번 475 is invalid.
# 10.5207/JIEIE.2020.34.4.052
# - 전체순번 476 is invalid.
# 10.5207/JIEIE.2018.32.9.041
# - 전체순번 477 is invalid.
# 10.1016/j.electacta.2017.12.015
# 10.1039/C4NR04293J
# 10.1016/j.electacta.2012.07.117
# 10.1002/cctc.201200458
# doi.org/10.1007/s11814-010-0212-9
# 10.4028/www.scientific.net/SSP.135.61
# 10.1016/S0167-2991(07)80128-5
# 10.9713/kcer.2011.49.1.021
# - 전체순번 464 is invalid.
# 10.1002/adfm.202110069
# 10.1002/adfm.202008801
# 10.1002/advs.202104598
# - 전체순번 452 is invalid.
# 10.1039/C8TA05916K
# 10.1002/smll.201703890
# 10.1039/C8TC02230E
# 10.1142/9789811240331_0003
# 10.1002/adfm.202003086
# 10.1016/j.ensm.2021.01.014
# 10.1002/smll.202205086
# 10.1016/j.cej.2019.01.008
# 10.1016/j.apsusc.2021.149578
# 10.1038/s41598-020-63769-z
# https://doi.org/10.1016/j.applthermaleng.2020.115153
# https://doi.org/10.1016/j.jngse.2022.104665
# https://doi.org/10.1016/j.compchemeng.2018.11.012
# https://doi.org/10.1016/j.jngse.2021.104374
# https://doi.org/10.1080/00221686.2020.1770875
# https://doi.org/10.1080/00221686.2018.1494051
# https://doi.org/10.1016/j.applthermaleng.2019.03.089
# https://doi.org/10.1016/j.ijhydene.2018.05.159
# https://doi.org/10.1016/j.ijhydene.2018.07.028
# https://doi.org/10.1016/j.seppur.2020.116636
# 10.1016/j.nanoen.2020.105266
# 10.1021/acsnano.0c02745
# 10.1002/smtd.202200116
# 10.1021/acsami.8b03057
# 10.5757/ASCT.2020.29.6.133
# 10.1039/d0ta05806h
# 10.1021/acsami.1c15648
# 10.1002/admt.202101105
# 10.1021/acsnano.9b03971
# 10.1016/j.carbon.2021.03.055
# 10.3390/en12091700
# # working on 800th article....
# 10.3390/su11226238
# 10.3390/en11102762
# 10.1109/ACCESS.2020.2982704
# 10.1109/LCOMM.2020.3027388
# 10.1587/transinf.2020EDL8094
# 10.1109/ACCESS.2021.3096810
# 10.14478/ace.2017.1124
# 10.5229/JKES.2018.21.1.6
# - 전체순번 408 is invalid.
# 10.1016/j.apcatb.2018.03.110
# 10.1016/j.apcatb.2019.04.015
# 10.1016/j.apcatb.2019.04.016
# 10.1016/j.cattod.2019.06.062
# 10.1016/j.cej.2020.125971
# 10.1016/j.cej.2020.127550
# 10.1021/jacsau.1c00124
# 10.1016/j.cej.2022.140537
# 10.1021/acsaem.0c00026, 공동 1저자, 교신저자,  저널 서브 표지 선정
# - 전체순번 397 is invalid.
# 10.1016/j.apcata.2017.11.023
# 10.1016/j.supflu.2018.11.015
# 10.1002/smll.201802915, 저널 백 표지 선정
# 10.1016/j.actamat.2020.11.015
# 10.1021/acs.chemmater.1c02145, 저널 서브 표지 선정
# 10.1039/d2dt00269h
# 10.1016/j.supflu.2017.09.032
# 10.14356/kona.2020002
# 10.3390/nano12091568
# https://doi.org/10.1016/j.solener.2020.10.022
# https://doi.org/10.4313/JKEM.2018.31.3.182
# - 전체순번 388 is invalid.
# 10.1109/JPHOTOV.2019.2898521
# 10.1109/JPHOTOV.2020.3032974
# 10.1109/JPHOTOV.2019.2928461
# https://doi.org/10.3390/en11040982
# https://doi.org/10.3390/app10217822
# https://doi.org/10.3390/app10030786
# https://doi.org/10.3390/app9245323
# https://doi.org/10.3390/app8101752
# 10.1016/j.jhazmat.2021.125780
# 10.1016/j.apsusc.2020.148643
# 10.1021/acs.iecr.9b01404
# 10.1016/j.apcata.2018.12.030
# 10.1016/j.apsusc.2019.145064
# doi.org/10.1016/j.cej.2021.132078
# 10.14478/ace.2018.1042
# 10.1016/j.jpowsour.2021.230828
# 10.1021/acsami.1c16896
# 10.1002/smll.201703194
# 10.1016/j.cap.2018.03.018
# https://doi.org/10.7735/ksmte.2020.29.2.134
# - 전체순번 374 is invalid.
# https://doi.org/10.1002/bkcs.12000
# 10.1002/aenm.202003609
# 10.1016/j.ensm.2021.06.011
# 10.1016/j.cej.2022.140798
# 10.1016/j.jpowsour.2018.08.034
# 10.1039/C9NR02016K
# 10.1016/j.electacta.2020.137520
# 10.1039/C8CC09184F
# 10.1039/D0NR02325F
# 10.1039/D2NR01515C
# 10.1039/C9TA02654A
# 10.1021/acsami.9b03866
# 10.1021/acssuschemeng.1c01497
# 10.1016/j.electacta.2021.139686
# 10.1039/C9CC05550A
# 10.1149/1945-7111/ac98e3
# 10.1088/1361-6528/ab2dd2
# 10.1039/C8TA05586F
# 10.1021/acsenergylett.2c01818
# 10.1002/adfm.202010095
# 10.1002/cssc.201900500
# 10.1039/D1TA04450H
# 10.1016/j.electacta.2020.136116
# 10.1016/j.jcat.2020.09.015
# 10.1016/j.jcou.2018.06.002
# 10.1016/j.apcata.2018.05.036
# 10.1007/s10562-019-02879-4
# 10.1016/j.catcom.2018.11.006
# 10.1007/s11164-022-04771-0
# 10.1007/s11144-022-02296-6
# 10.1007/s11814-017-0343-3
# https://doi.org/10.3390/nano12122008
# https://doi.org/10.1016/j.jmrt.2021.07.127
# https://doi.org/10.1016/j.ceramint.2021.03.196
# https://doi.org/10.3390/nano11092195
# https://doi.org/10.1016/j.electacta.2018.11.167
# 10.1002/aenm.201701901
# 10.1002/aenm.201803476
# 10.1002/aenm.201902740
# 10.1002/aenm.202001799
# 10.1016/j.matt.2020.08.202
# 10.1038/s41586-021-03964-8
# 10.1002/adfm.202110473
# 10.1002/aenm.202200181
# 10.1021/acsenergylett.2c00637
# 10.1038/s41560-022-01086-7
# 10.1016/j.cej.2022.135603
# 10.1021/acs.estlett.9b00541
# 10.1016/j.cej.2021.134233
# 10.1016/j.desal.2020.114778
# 10.1016/j.desal.2017.09.032
# 10.1021/acssuschemeng.1c00848
# # working on 900th article....
# 10.1021/acssuschemeng.1c04419
# 10.1016/j.jece.2021.106876
# 10.1016/j.enconman.2020.113187
# 10.1016/j.energy.2020.119166
# 10.1016/j.apenergy.2021.117520
# 10.1016/j.energy.2022.123168
# 10.1016/j.enconman.2018.12.091
# 10.1007/s12206-018-0920-3
# https://doi.org/10.3390/ijms21124208
# https://doi.org/10.1007/s10955-019-02371-8
# https://doi.org/10.1109/ACCESS.2019.2960179
# https://doi.org/10.3390/s18103234
# 10.1021/acsnano.8b06268
# 10.1016/j.electacta.2022.140427
# 10.1016/j.ijhydene.2018.07.173
# 10.1016/j.cej.2022.140091
# 10.1016/j.jpowsour.2020.229291
# 10.1038/s41598-022-18464-6
# 10.1021/jacs.6b09470
# 10.1016/j.ijhydene.2017.05.119
# 10.1016/j.jpowsour.2016.08.006
# 10.1016/j.jpowsour.2016.03.063
# 10.1109/ACCESS.2022.3173648
# 10.1109/ACCESS.2022.3228245
# - 전체순번 297 is invalid.
# 10.1109/ACCESS.2022.3195991
# https://doi.org/10.1016/j.displa.2022.102233
# https://doi.org/10.3390/s22072743
# 10.1039/d0ee02859b
# 10.1002/adma.202004657
# 10.1002/adma.202004985
# 10.1002/aenm.201903846
# 10.1002/aenm.202002084
# 10.1002/aenm.201702872
# 10.1021/acs.chemmater.9b00639
# 10.1039/c8ee02242a
# 10.1002/aenm.202003829
# 10.1039/c8ta00479j
# 10.1063/5.0125125
# 10.1038/s41598-019-52480-3
# 10.1103/PhysRevE.102.052501
# 10.1103/PhysRevE.98.042503
# 10.1007/s11095-019-2570-2
# 10.1016/j.chemphys.2021.111231
# 10.1002/bkcs.12497
# 10.1021/acs.jpcb.9b07236
# 10.1021/acs.macromol.1c01937
# 10.3390/polym13224049
# 10.1039/d2ee01128j
# 10.1016/j.jcp.2022.111614
# 10.1016/j.jnnfm.2021.104650
# 10.1016/j.jnnfm.2022.104972
# - 전체순번 267 is invalid.
# 10.1007/s13367-021-0006-0
# 10.1007/s13367-022-00030-1
# 10.1007/s12221-021-0121-z
# 10.1007/s13367-021-0009-x
# 10.1007/s13367-020-0020-7
# 10.1007/s13367-019-0014-5
# 10.1007/s13367-018-0003-0
# 10.1016/j.jclepro.2022.135034
# 10.1016/j.ijhydene.2020.06.095
# 10.1016/j.rser.2022.112556
# 10.1016/j.cherd.2022.10.021
# 10.1016/j.jiec.2022.05.051
# 10.1021/acs.iecr.0c01957
# 10.1016/j.compchemeng.2018.03.023
# 10.1007/s11814-017-0235-6
# 10.7842/kigas.2018.22.5.24
# - 전체순번 264 is invalid.
# 10.1002/adfm.202211358
# 10.1002/smtd.202100054
# 10.1016/j.jclepro.2020.121912
# 10.1016/j.mtadv.2022.100232
# 10.1016/j.jpowsour.2020.228067
# 10.1002/solr.202200485
# 10.1016/j.mtchem.2022.101224
# 10.1021/acsphotonics.0c01952
# 10.3390/polym12092061
# 10.1021/acs.jpcc.8b04613
# 10.3390/ma11081417
# 10.1175/MWR-D-19-0002.1
# 10.1175/MWR-D-21-0284.1
# 10.3390/atmos13050779
# 10.1175/MWR-D-22-0136.1.
# - 전체순번 244 is invalid.
# 10.1016/j.joule.2021.08.004
# 10.1016/j.ijheatmasstransfer.2020.119591
# 10.1016/j.ijheatmasstransfer.2021.121510
# 10.1016/j.apcatb.2020.119292
# 10.1039/C9TA11048H
# 10.1002/cctc.201901549
# 10.1016/j.apcata.2020.117737
# 10.1039/C9CC09988C
# 10.1016/j.ijhydene.2018.06.141
# 10.1016/j.ijhydene.2019.09.087
# 10.1016/j.jcou.2019.03.004
# online published, doi/10.1002/aenm.202203198
# online published, doi/10.1007/s40684-022-00485-1
# doi/10.1021/accountsmr.1c00187
# 10.1016/j.apsusc.2022.155040
# 10.1016/j.apsusc.2019.145064
# 10.1016/j.cej.2021.130445
# 10.1016/j.ijhydene.2020.09.054
# # working on 1000th article....
# 10.1016/j.ijhydene.2020.03.062
# 10.1016/j.apcata.2018.12.035
# 10.1021/acs.iecr.9b05343
# 10.1021/acs.iecr.0c06126
# 10.1080/09593330.2018.1554004
# 10.1039/C7RA11294G
# 10.1021/acs.iecr.2c01518
# 10.1016/j.apcatb.2022.121167
# 10.1016/j.cej.2022.134676
# 10.1016/j.apsusc.2019.144906
# 10.1021/acsomega.7b00792
# 10.1063/5.0086903
# 10.1007/s40042-022-00617-5
# 10.1002/cptc.202200177
# 10.1021/acs.jpcc.9b11846
# 10.1002/asia.201800020
# 10.1002/adom.201801348
# 10.1016/j.carbon.2020.06.041
# 10.1016/j.polymer.2021.124004
# 10.1002/smll.202205086
# 10.1016/j.jpowsour.2020.228587
# 10.1016/j.electacta.2022.140219
# 10.1016/j.electacta.2022.140092
# 10.1016/j.apsusc.2021.149578
# 10.1016/j.cattod.2019.07.001
# 10.1149/1945-7111/ac0aaf
# 10.1016/j.ijhydene.2019.04.169
# 10.1021/acs.jpcc.1c02805
# 10.1016/j.energy.2021.121791
# 10.3390/polym13142364
# 10.1016/j.memsci.2022.120393
# 10.3390/polym12091871
# 10.1016/j.cej.2019.122679
# 10.1039/C9TC06345E
# 10.1016/j.apsusc.2020.145449
# 10.1016/j.jpowsour.2020.228860
# 10.1039/D1TC03362J
# 10.1016/j.jiec.2020.05.006
# 10.1002/er.7200
# 10.1016/j.apsusc.2022.155665
# - 전체순번 188 is invalid.
# 10.1016/j.jechem.2020.10.042
# 10.1039/C9TC03071A
# 10.1021/acsnano.0c07549
# 10.1039/C9TA05883D
# 10.1021/acs.jpcc.9b10191
# 10.1063/1.5042076
# 10.1016/j.nanoen.2022.107813
# 10.1039/C9TA08438J
# 10.1039/C8TA04137G
# 10.1039/C9NR01113G
# 10.1021/acs.jpcc.1c00454
# 10.1016/j.susc.2018.09.004
# 10.1109/TPEL.2020.2982969
# 10.1109/TPEL.2018.2857209
# 10.1109/TPEL.2018.2811678
# 10.1021/acs.jpcc.7b09294
# 10.1039/C8CP03801E
# 10.1039/C8TA07141A
# 10.1016/j.jiec.2018.10.024
# 10.1016/j.coelec.2018.11.016
# 10.1016/j.apsusc.2018.11.147
# 10.1021/acssuschemeng.9b07166
# 10.1016/j.jpowsour.2020.227998
# 10.1016/j.apcatb.2020.118927
# 10.1021/acssuschemeng.0c02981
# 10.1039/d0qm01113d
# 10.1002/adfm.202209543
# 10.1002/adma.202203285
# 10.1016/j.cej.2022.140091
# 11월 제출
# - 전체순번 166 is invalid.
# 12월 제출
# - 전체순번 167 is invalid.
# 10.1016/j.enbuild.2021.111449
# 10.1016/j.csite.2022.102511
# 10.3390/en14227527
# 10.3390/en13102667
# 10.3390/en12224307
# 10.1039/C9TA10704E
# 10.1039/C8TC06491A
# 10.3390/nano11123379
# 10.3740/MRSK.2022.32.2.98
# 10.5695/JSSE.2022.55.2.51
# - 전체순번 146 is invalid.
# 10.1016/j.jobe.2022.105241
# 10.1016/j.renene.2021.12.094
# 10.1016/j.enbuild.2021.111825
# 10.1016/j.enbuild.2020.110623
# 10.1016/j.geothermics.2022.102373
# 10.1016/j.jobe.2021.103411
# 10.1016/j.energy.2022.124890
# 10.3390/en15020528
# 10.3390/en13205524
# 10.3390/en12173304
# 10.3390/en12040651
# 10.3390/en11071786
# 10.3390/en15114019
# 10.3390/en15072317
# 10.3390/en15030698
# 10.3390/en13195211
# 10.3390/en13030554
# 10.3390/en13010085
# 10.3390/en11123485
# # working on 1100th article....
# 10.3390/app9245379
# 10.3390/app10051680
# 10.5050/KSNVE.2020.30.2.211
# - 전체순번 121 is invalid.
# 10.1007/s10072-022-06006-x
# 10.1080/15732479.2022.2097267
# 10.3390/s19112631
# 10.3390/app10176078
# 10.12989/sem.2021.77.1.089
# 10.1109/ACCESS.2021.3121873
# 10.1016/j.sna.2021.113317
# 10.1088/1361-665
# 10.1088/1361-665
# 10.1007/s00158-022-03445-0
# 10.1016/j.jssc.2020.121767
# 10.1039/c9cp03258d
# 10.1016/j.ijggc.2018.12.010
# 10.1021/acs.jpcc.8b04895
# 10.1016/j.jssc.2018.08.013
# 10.1016/j.jssc.2018.04.025
# 10.1016/j.joule.2019.11.008
# 10.1021/acsnano.1c04585
# 10.1016/j.xcrp.2020.100143
# 10.1039/C9TA12792E
# 10.1016/j.apsusc.2020.145461
# 10.1149/09208.0741ecst
# 10.1016/j.cattod.2019.07.046
# 10.1016/j.cattod.2019.12.022
# 10.7316/KHNES.2018.29.3.260
# - 전체순번 99 is invalid.
# 없음
# 10.1109/JESTPE.2019.2963124
# 10.1109/JESTPE.2019.2918182
# 10.1007/s43236-021-00254-4
# 10.1109/ACCESS.2021.3085585
# 10.3390/electronics10091029
# 10.3390/electronics10010087
# 10.21289/KSIC.2022.25.1.111
# - 전체순번 87 is invalid.
# 10.21289/KSIC.2021.24.6.919
# - 전체순번 88 is invalid.
# 10.7471/ikeee.2018.22.3.630
# - 전체순번 89 is invalid.
# 10.21289/KSIC.2019.22.2.219
# - 전체순번 90 is invalid.
# 10.1002/adfm.202001775
# 10.1002/advs.202105436
# 10.1039/c9ta06274b
# 10.1021/acsaem.2c01350
# 10.1016/j.apsusc.2021.151988
# 10.1016/j.apsusc.2021.149844
# 10.1016/j.solmat.2021.111010
# 10.1016/j.jallcom.2020.154626
# 10.3390/en13030688
# 10.1016/j.buildenv.2021.108492
# 10.1016/j.buildenv.2021.107744
# 10.1016/j.scs.2020.102292
# 10.1080/14733315.2020.1818445
# 10.1177/1420326X18770238
# 10.1016/j.buildenv.2022.109060
# 10.1016/j.buildenv.2022.109877
# 10.1016/j.buildenv.2022.109479
# 10.12813/kieae.2022.22.2.033
# - 전체순번 74 is invalid.
# 10.1016/j.jallcom.2022.168255
# - 전체순번 61 is invalid.
# 10.1016/j.jmmm.2022.169755
# 10.1016/j.jallcom.2020.157241
# 10.1016/j.matchar.2019.110063
# 10.1002/adom.201970050
# 10.1016/j.apenergy.2017.11.096
# 10.1021/acsomega.8b01552
# 10.1021/acsaem.9b00522
# 10.1016/j.mattod.2020.01.002
# 10.1002/adfm.202206561 / 첫번째 저자와 공동 제1저자임.
# 10.1021/acsami.2c01892
# 10.1016/j.jallcom.2022.165560
# 10.1016/j.solener.2022.01.053
# 10.1039/D0TA06937J
# 10.1039/C9SE00778D
# 10.1021/acsami.9b16192
# 10.1021/acsami.9b12565
# 10.1002/aenm.201801501
# 10.1016/j.nanoen.2017.12.031
# 10.1016/j.jechem.2022.10.004
# 10.1016/j.jiec.2021.02.028
# 10.1016/j.nanoen.2020.105206
# 10.1088/1361-6528/aba3dc
# 10.1016/j.solmat.2019.02.024
# 10.1039/C9TA08265D
# 10.1166/jno.2018.2401
# - No.1182 is not accessible in Scopus.
# 10.1109/PVSC.2018.8547446
# 10.1016/j.cap.2018.03.024
# 10.1016/j.mattod.2018.03.038
# 10.1016/j.cap.2017.12.004
# 10.3938/jkps.71.1012
# 10.1016/j.cej.2022.139561
# 10.1016/j.cej.2022.134676
# 10.1002/cctc.202000879
# 10.1002/adma.202203285
# 10.1039/C9TA07700F
# 10.1021/acssuschemeng.2c04995
# 10.1021/acssuschemeng.0c01774
# - 전체순번 31 is invalid.
# 10.1016/j.jece.2022.108325
# 10.1016/j.apsusc.2022.152894
# 10.1016/j.apcata.2020.117970
# IF (3.252)
# IF (3.252)
# # working on 1200th article....
# IF (8.634)
# - 전체순번 15 is invalid.
# IF (3.252)
# - No.1201 is not accessible in Scopus.
# IF (11.533)
# IF (3.252)
# IF (3.889)
# 1.5 kW 다리우스 풍력터빈 현장 실증 및 성능분석
# - 전체순번 20 is invalid.
# 에너지 자립 마을 개발을 위한 공력 실증 데이터 분석
# - 전체순번 21 is invalid.
# 수직형 소형풍력터빈의 비정상 익력 평가
# - 전체순번 22 is invalid.
# IF (2.679)
# IF (3.252)
# 10.3390/polym10121364
# 10.1007/s13391-019-00129-8
# 10.1002/adfm.201800369
# 10.1016/j.apsusc.2018.04.085
# 10.1038/s41598-020-68127-7
# 10.1021/acsenergylett.0c01887
# 10.1002/er.7761
# 10.1016/j.solener.2018.11.061
# 10.1186/s11671-017-2401-5
# 10.1007/s13391-018-0095-1
# 10.1007/s13391-018-0042-1
# 10.1116/1.5052287

# %% [markdown]
# ## Semantic Scholar

# %%
start = 0
df_applicants = pd.read_excel(f"applicants_fill_from{start}_to{end}.xlsx")
df_applicants.head(3)
# Out:
#    전체순번  지원번호 내 순번         지원번호   성명         영문이름   지원자 입력 영문명   분야  \
# 0  1217          1  0121-000001  하수룡  Su Ryong Ha  Su Ryong Ha  태양광
# 1  1218          2  0121-000001  하수룡  Su Ryong Ha  Su Ryong Ha  태양광
# 2  1219          3  0121-000001  하수룡  Su Ryong Ha  Su Ryong Ha  태양광
#
#                               DOI  \
# 0              10.1039/C9TA11854C
# 1          10.1021/acsami.2c01216
# 2  10.1016/j.jpowsour.2020.227903
#
#                                                  논문명  SCIE구분    저자순위 저자구분  \
# 0  Molecular aggregation method for perovskite– f...  국외SCIE  (1/17)  주저자
# 1  Simple-Structured Low-Cost Dopant-Free Hole Tr...  국외SCIE   (2/8)  주저자
# 2  Dynamic casting in combination with ramped ann...  국외SCIE   (2/6)  주저자
#
#   게재구분                                                저널명         게재일  \
# 0   게재    Journal of Materials Chemistry A, 2020, 8, 1326  2019.12.20
# 1   게재  ACS Applied Materials & Interfaces, 2022, 14, ...  2022.03.08
# 2   게재        Journal of Power Sources, 2020, 453, 227903  2020.02.18
#
#                           출판사       ISSN 논문구분\n(SCIE) Publication Date  \
# 0  Royal Society of Chemistry  2050-7488            Y             2020
# 1   American Chemical Society  1944-8244            Y      MAR 23 2022
# 2                    Elsevier  0378-7753            Y      MAR 31 2020
#
#    #citation Publication Year journal impact factor  \
# 0       13.0                                 12.732
# 1        1.0                       IF 미발급: 2022년 출판
# 2       11.0                                  9.127
#
#    2021\njournal\nimpact\nfactor 2021 journal impact factor percentile  \
# 0                         14.511                                 92.86
# 1                         10.383                                 85.94
# 2                          9.794                                 88.33
#
#       1st Author 1ST AUTHOR\n(Y/N)  Reprint Author  REPRINT AUTHOR\n(Y/N)  \
# 0   Ha, Su Ryong                 Y             NaN                    NaN
# 1  Jeong, Won Jo                 N             NaN                    NaN
# 2     Seo, Yejin                 N             NaN                    NaN
#
#                       Source\n(Journal) volume issue Notes
# 0      JOURNAL OF MATERIALS CHEMISTRY A      8     3   NaN
# 1  ACS APPLIED MATERIALS AND INTERFACES     14    11   NaN
# 2              JOURNAL OF POWER SOURCES    453   NaN   NaN

# %%
# Notes에 "Scopus에서 doi 및 title 검색 불가: 확인 필요"라고 적힌 것들만 대상.
df_2nd = df_applicants.loc[df_applicants["Notes"].str.contains("불가")==True]
print(df_2nd.shape)
df_2nd.head(3)
# Out:
# (68, 31)
#     전체순번  지원번호 내 순번         지원번호   성명          영문이름   지원자 입력 영문명       분야  \
# 18  1205          3  0121-000006  김기봉    Kibong Kim   Kibong Kim     기계설비
# 19  1206          4  0121-000006  김기봉    Kibong Kim   Kibong Kim     기계설비
# 94  1122          1  0121-000024  김국한  Kim, Kookhan  Kookhan Kim  이차전지(Ⅰ)
#
#                               DOI  \
# 18        10.7849/ksnre.2021.2022
# 19     10.7836/kses.2021.41.1.013
# 94  10.1021/acsenergylett.2c00974
#
#                                                   논문명    SCIE구분    저자순위  저자구분  \
# 18           방음벽 PVT의 공기 유로 설계를 위한 CFD 시뮬레이션 사전 분석 연구  국내 등재학술지   (2/4)  제2저자
# 19                       국제 기준 공기식 태양열 집열기 열 성능 평가 연구  국내 등재학술지   (2/4)  제2저자
# 94  Surface Roughness-Independent Homogeneous Lith...    국외SCIE  (2/10)   주저자
#
#    게재구분                                                저널명         게재일  \
# 18   게재                New & Renewable Energy, 17, 3, 2021  2021.09.03
# 19   게재  Journal of the Korean Solar Society, 14, 1, 13...  2021.01.04
# 94   게재           ACS Energy Letters 7, 7, 2219-2227, 2022  2022.06.06
#
#                           출판사       ISSN 논문구분\n(SCIE) Publication Date  \
# 18                 한국신재생에너지학회  1738-3935          NaN              NaN
# 19                  한국태양에너지학회  1598-6411          NaN              NaN
# 94  American Chemical Society          -          NaN              NaN
#
#     #citation Publication Year journal impact factor  \
# 18        NaN                                    NaN
# 19        NaN                                    NaN
# 94        NaN                                    NaN
#
#     2021\njournal\nimpact\nfactor 2021 journal impact factor percentile  \
# 18                            NaN                                   NaN
# 19                            NaN                                   NaN
# 94                            NaN                                   NaN
#
#    1st Author 1ST AUTHOR\n(Y/N)  Reprint Author  REPRINT AUTHOR\n(Y/N)  \
# 18        NaN               NaN             NaN                    NaN
# 19        NaN               NaN             NaN                    NaN
# 94        NaN               NaN             NaN                    NaN
#
#    Source\n(Journal) volume issue                              Notes
# 18               NaN    NaN   NaN  Scopus에서 doi 및 title 검색 불가: 확인 필요
# 19               NaN    NaN   NaN  Scopus에서 doi 및 title 검색 불가: 확인 필요
# 94               NaN    NaN   NaN  Scopus에서 doi 및 title 검색 불가: 확인 필요

# %% [markdown]
# ### doi

# %%
start_2nd = 0
end_2nd = df_2nd.shape[0]

# %%
df.index
# Out:
# Index(['전체순번', '지원번호 내 순번', '지원번호', '성명', '영문이름', '지원자 입력 영문명', '분야', 'DOI',
#        '논문명', 'SCIE구분', '저자순위', '저자구분', '게재구분', '저널명', '게재일', '출판사', 'ISSN',
#        '논문구분\n(SCIE)', 'Publication Date', '#citation',
#        'Publication Year journal impact factor',
#        '2021\njournal\nimpact\nfactor',
#        '2021 journal impact factor percentile', '1st Author',
#        '1ST AUTHOR\n(Y/N)', 'Reprint Author', 'REPRINT AUTHOR\n(Y/N)',
#        'Source\n(Journal)', 'volume', 'issue', 'Notes'],
#       dtype='object')

# %%
for i in range(start_2nd, end_2nd):
    
    # verbose: iteration
    if i%100 == 0 and i > 0:
        print(f"# working on {i}th article....")
        
    df = df_2nd.iloc[i]
    
    idx = df.name
    doi = df["DOI"]
    notes = ["Scopus에서 doi 및 title 검색 불가: SemanticScholar 활용 시도"]
    URL = f"https://api.semanticscholar.org/graph/v1/paper/DOI:{doi}?fields=title,venue,year,citationCount,authors,tldr"
    try:
        response = requests.get(URL)

        if response.status_code:
            ### read data
            ss_info = response.json()
            title = ss_info["title"]
            publicationName = ss_info["venue"]
            year = ss_info["year"]
            citation = ss_info["citationCount"]
            tldr = ss_info["tldr"]
            authors_raw = [a["name"] for a in ss_info["authors"]]
            authors_reg = [regularize(n) for n in authors_raw]
            
            ### SCIE 여부 (Y/N)
            # index of publication at JCR data
            index_remark = get_pub_index(publicationName, dfs_JCR_SCIE[str(YEAR_REMARK)])

            # decision
            if len(index_remark) > 0:
                df_applicants["논문구분\n(SCIE)"].loc[idx] = "Y"
            else:
                df_applicants["논문구분\n(SCIE)"].loc[idx] = "N"
                notes.append("JCR 목록에 없음")
                df_applicants["Notes"].loc[idx] = "\n".join(notes)

            ### Publication Date
            df_applicants["Publication Date"].loc[idx] = year
            df_applicants["#citation"].loc[idx] = citation

            ### Impact Factor @Publication year and @remark year
            if year < YEAR_START:
                notes.append(f"{YEAR_START-1} 이전 논문")
                df_applicants["Notes"].loc[idx] = "\n".join(notes)

            elif year <= YEAR_END:
                index_pub = get_pub_index(publicationName, dfs_JCR_SCIE[str(year)])
                if len(index_pub) > 0:
                    index_pub = index_pub[0]
                    jif_n = str(dfs_JCR_SCIE[str(year)]["IMPACT_FACTOR"][index_pub])
                else:
                    # JCR Data에 해당 publication이 없음
                    notes.append(f"IF를 찾지 못함")
                    df_applicants["Notes"].loc[idx] = "\n".join(notes)
                    jif_n = f"IF 미발급: JCR Data에 없음"

            else:
                jif_n = f"IF 미발급: {year}년 출판"

            df_applicants["Publication Year journal impact factor"].loc[idx] = jif_n

            ### Impact Factor Percentile @remark year
            if index_remark.size > 0:
                df_applicants["2020\njournal\nimpact\nfactor"].loc[idx] = str(dfs_JCR_SCIE["2020"]["IMPACT_FACTOR"][index_remark[0]])
                ifp = dfs_JCR_SCIE[str(YEAR_REMARK)].loc[index_remark, "JIF_PERCENTILE"]
                df_applicants["2020 journal impact factor percentile"].loc[idx] = str(ifp.values[0])
            else:
                df_applicants["2020 journal impact factor percentile"].loc[idx] = "mrnIF 없음"
                
           ### Author data
            # authors in paper
            if info_scopus.author_names:
                
                # applicants name
                name = df["영문명"]
                name_paper = df["논문 내 영문명"]
                name_swap = ", ".join(name.split(" ")[1:] + name.split(" ")[:1]).rstrip(",")
                name_paper_swap = " ".join([name_paper.split(" ")[-1]] + name_paper.split(" ")[:-1])
                name_reg = regularize(df["영문명"])
                name_paper_reg = regularize(df["논문 내 영문명"])
                name_swap_reg = regularize(", ".join(name[1:] + name[:1]))
                name_paper_swap_reg = regularize(name_paper_swap)

                # name matching. 우선순위대로
                if any([name_paper in a for a in authors_raw]):
                    idx_author = [name_paper in a for a in authors_raw].index(True)
                elif any([name in a for a in authors_raw]):
                    idx_author = [name in a for a in authors_raw].index(True)
                elif any([name_swap in a for a in authors_raw]):
                    idx_author = [name_swap in a for a in authors_raw].index(True)
                elif any([name_paper_swap in a for a in authors_raw]):
                    idx_author = [name_paper_swap in a for a in authors_raw].index(True)
                elif any([name_paper_reg in a for a in authors_reg]):
                    idx_author = [name_paper_reg in a for a in authors_reg].index(True)
                elif any([name_reg in a for a in authors_reg]):
                    idx_author = [name_reg in a for a in authors_reg].index(True)
                elif any([name_swap_reg in a for a in authors_reg]):
                    idx_author = [name_swap_reg in a for a in authors_reg].index(True)
                elif any([name_paper_swap_reg in a for a in authors_reg]):
                    idx_author = [name_paper_swap_reg in a for a in authors_reg].index(True)
                else:    # 이니셜로만 되어 있는 것은 아닌지 확인
                    if "," in name:  # 이름에 ","가 있는 경우 : "성, 이름"으로 구성되어 있는 것으로 가정
                        familyname, givenname = name.split(", ")[0].lower(), name.split(", ")[1].lower()
                    else:            # 이름에 ","가 없는 경우 : "이름 성"으로 구성되어 있는 것으로 가정.
                        familyname, givenname = name.split(" ")[-1].lower(), "".join(name.split(" ")[:-1]).lower()

                    name_TF = [True if ((n[0] == familyname and len(set(n[1:])-set(givenname))==0) or 
                                        (n[-1]== familyname and len(set(n[:-1])-set(givenname))==0)) 
                               else False 
                               for n in authors_reg]
                    name_scopus_err_reg = regularize(" ".join([*givenname.split(" ")[1:], familyname, givenname.split(" ")[0]]))

                    if len(np.where(np.array(name_TF)==True)[0]) > 0:
                        idx_author = np.where(np.array(name_TF)==True)[0][0]
                        notes.append("확인 필요: 논문 저자 이름이 약어로 표현됨. 확인 필요.")

                    # Lim, Suk Hyun이 Scopus DB에 Hyun Lim, Suk으로 입력된 사례: 10.1016/j.fuel.2021.122481
                    elif name_scopus_err_reg in authors_reg:
                        idx_author = authors_reg.index(name_scopus_err_reg)
                        notes.append("확인 필요: ScopusDB에 이름이 한 글자씩 밀려서 잘못 입력된 듯함.")
                    else:
                        idx_author = None
                        notes.append("확인 필요: 저자 명단에서 지원자를 찾지 못함.")

                # first author
                first_author = authors_raw[0]
                if idx_author == 0:
                    first_author_yn = "Y"
                else:
                    first_author_yn = "N"

                df_applicants["1st Author"].loc[idx] = first_author
                df_applicants["1ST AUTHOR\n(Y/N)"].loc[idx] = first_author_yn 
            
            ### Publication
            df_applicants["Source\n(Journal)"].loc[idx] = publicationName.upper()
            
            
    except:
        pass
    
    # write in every step
    df_applicants["Notes"].loc[idx] = "\n".join(notes)
    df_applicants.to_excel(f"applicants_fill_from{start}_to{end}_ss.xlsx", index=False)
