# %% [markdown]
# * code by Sihyun You (2021.12.28.)
# * edit by Jehyun Lee (2021.12.30.)
# * revised for mrnIF by Jehyun Lee (2022.01.08.)

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from pybliometrics.scopus import ScopusSearch
from bs4 import BeautifulSoup
import requests, json
from docx import Document
from copy import deepcopy

# %%
# Scopus API Keys
from my_apikeys import APIKeys

# %%
# subscriber (Institute: True. Home: False)
try:
    s_sample = ScopusSearch(f"DOI (10.1038/s41598-021-83315-9)").results[0]
    subscriber=True
except:
    subscriber=False

print(f"subscriber={subscriber}")
# Out:
# subscriber=True

# %%
def regularize_date_publication(_str):
    _str = _str.replace(",", "")
    token_date = _str.split(' ')
    if len(token_date) == 1: # year only
        year = _str
        s = _str
    elif (re.match('[0-9]', token_date[0])):
        day, month, year = token_date[0], token_date[1][:3].upper(), token_date[2]
        s = ' '.join([month, day, year])
    elif (re.match('[A-Za-z]', token_date[0]) and re.match('[0-9]', token_date[1]) and int(token_date[1])<32):    
        month, day, year = token_date[0][:3].upper(), token_date[1], token_date[2]
        s = ' '.join([month, day, year])
    else:
        month, year = token_date[0][:3].upper(), token_date[1]
        s = ' '.join([month, year])
        
    return (int(year), s)

def get_pub_index(_pub_name, _df):
    list_title = _df['TITLE'].map(regularize)
    pub_index = np.where(regularize(_pub_name) == list_title)[0]
    if len(pub_index) > 0:
        return pub_index
    return np.array([])

def get_pub_index_eissn(_pub_eissn, _df):
    list_eissn = _df['EISSN'].str.replace("-","").values
    pub_index = np.where(_pub_eissn == list_eissn)[0]
    if len(pub_index) > 0:
        return pub_index
    return np.array([])

def regularize(_str):
    return re.sub('[^A-Za-z0-9]+', '', re.sub('&', 'and', _str)).lower()       

def regularize_space(_str):
    return re.sub('[^A-Za-z0-9]+', ' ', re.sub('&', 'and', _str)).lower()

# %%
pd.set_option("mode.chained_assignment", None)
pd.set_option("display.max_columns", None)
dfs_JCR_SCIE = {}
YEAR_START, YEAR_REMARK, YEAR_THIS = 2016, 2020, 2021

# %%
for y in range(YEAR_START, YEAR_THIS):
    print(f"{y}년도 시트를 로딩중입니다.")
    dfs_JCR_SCIE.update({str(y):pd.read_excel("./data/JCR_SCIE_(2016-2020)_merged.xlsx", sheet_name=f"JCR {y}")})
# Out:
# 2016년도 시트를 로딩중입니다.
# 2017년도 시트를 로딩중입니다.
# 2018년도 시트를 로딩중입니다.
# 2019년도 시트를 로딩중입니다.
# 2020년도 시트를 로딩중입니다.

# %%
# EISSN 인가
for k in dfs_JCR_SCIE.keys():
    col_capitals = np.array([c.upper() for c in dfs_JCR_SCIE[k].columns])
    if "EISSN" in col_capitals:
        idx_eissn = np.where("EISSN" == col_capitals)[0][0]
        dfs_JCR_SCIE[k] = dfs_JCR_SCIE[k].rename(columns={dfs_JCR_SCIE[k].columns[idx_eissn]:"EISSN"})

EISSN_2019 = dfs_JCR_SCIE["2019"][["Title20", "ISO_ABBREV", "TITLE", "ISSN", "EISSN"]]
EISSN_2020 = dfs_JCR_SCIE["2020"][["Title20", "ISO_ABBREV", "TITLE", "ISSN", "EISSN"]]
EISSN = pd.concat([EISSN_2019, EISSN_2020], axis=0).drop_duplicates("ISSN")

for k in dfs_JCR_SCIE.keys():
    col_capitals = np.array([c.upper() for c in dfs_JCR_SCIE[k].columns])
    if "EISSN" not in col_capitals:
        dfs_JCR_SCIE[k] = dfs_JCR_SCIE[k].merge(EISSN, how="left", on=["Title20", "ISO_ABBREV", "TITLE", "ISSN"])

# %%
dfs_JCR_SCIE.keys()
# Out:
# dict_keys(['2016', '2017', '2018', '2019', '2020'])

# %%
df_applicants = pd.read_excel("./data/HR_input.xlsx", header=1, dtype={"UT":str})

# display example
df_applicants.head(3)
# Out:
#    전체순번  수험번호내 순번         수험번호   이름             영문명  \
# 0  1409         2  0088-000276  김재형  Kim, Jae Hyung
# 1   683         3  0088-000129  유정원   Yoo, Jeongwon
# 2   684         4  0088-000129  유정원   Yoo, Jeongwon
#
#                                                 논문제목        게재일자  \
# 0  A General Strategy to Atomically Dispersed Pre...  2020.01.30
# 1  Investigation of intrinsic toroidal rotation s...  2017.07.12
# 2  Experimental evidence of intrinsic ohmic rotat...  2018.04.25
#
#                  지원자 입력 DOI                   수정 DOI  SCIE구분    역할  \
# 0  /10.1021/acsnano.9b08494  10.1021/acsnano.9b08494  국외SCIE   주저자
# 1        /10.1063/1.4991397        10.1063/1.4991397  국외SCIE   주저자
# 2        /10.1063/1.5026905        10.1063/1.5026905  국외SCIE  제2저자
#
#                                    게재지명             출판사 ISSN  논문구분\n(SCIE)  \
# 0         ACS Nano 2020, 14, 1990-2001.             ACS    -           NaN
# 1  PHYSICS OF PLASMAS 24, 072510 (2017)  AIP Publishing    -           NaN
# 2      Phys. Plasmas 25, 044502 (2018);  AIP Publishing    -           NaN
#
#    Publication Date  #citation  Publication Year journal impact factor  \
# 0               NaN        NaN                                     NaN
# 1               NaN        NaN                                     NaN
# 2               NaN        NaN                                     NaN
#
#    2020\njournal\nimpact\nfactor  2020 journal impact factor percentile  \
# 0                            NaN                                    NaN
# 1                            NaN                                    NaN
# 2                            NaN                                    NaN
#
#    1st Author  1ST AUTHOR\n(Y/N)  Reprint Author  REPRINT AUTHOR\n(Y/N)  \
# 0         NaN                NaN             NaN                    NaN
# 1         NaN                NaN             NaN                    NaN
# 2         NaN                NaN             NaN                    NaN
#
#    Source\n(Journal)  volume  issue  Notes
# 0                NaN     NaN    NaN    NaN
# 1                NaN     NaN    NaN    NaN
# 2                NaN     NaN    NaN    NaN

# %%
list_title = df_applicants["논문제목"].values
list_name_kr = df_applicants["이름"].values
list_name_en = df_applicants["영문명"].values
list_doi = df_applicants["수정 DOI"].values

# %%
print(len(list_doi), len(list_title))
# Out:
# 1528 1528

# %%
df_applicants.columns
# Out:
# Index(['전체순번', '수험번호내 순번', '수험번호', '이름', '영문명', '논문제목', '게재일자', '지원자 입력 DOI',
#        '수정 DOI', 'SCIE구분', '역할', '게재지명', '출판사', 'ISSN', '논문구분\n(SCIE)',
#        'Publication Date', '#citation',
#        'Publication Year journal impact factor',
#        '2020\njournal\nimpact\nfactor',
#        '2020 journal impact factor percentile', '1st Author',
#        '1ST AUTHOR\n(Y/N)', 'Reprint Author', 'REPRINT AUTHOR\n(Y/N)',
#        'Source\n(Journal)', 'volume', 'issue', 'Notes'],
#       dtype='object')

# %%
doi = "10.1002/aenm.202003306"
s = ScopusSearch(f"DOI ({doi})", download=True, subscriber=subscriber).results

# %%
xmls = []

for i, (doi, title) in enumerate(zip(list_doi, list_title)):
    s = ScopusSearch(f"DOI ({doi})", download=True, subscriber=subscriber).results
    if s == None:
        try:
            s = ScopusSearch(f"TITLE ({title})", download=True, subscriber=subscriber).results
            if s != None:
                doi = s[0].doi
                df_applicants["Notes"][i] = f"DOI 오류: {doi}"
            else:
                print(f"- No.{i} is invalid.")
                df_applicants["Notes"][i] = "doi 및 title 확인 필요"
                continue
        except:
            print(f"- No.{i} is not accessible in Scopus.")
            df_applicants["Notes"][i] = "Scopus에서 접근 불가. 확인 필요"
            continue
            
        
    info_scopus = s[0]

    index_remark = get_pub_index(info_scopus.publicationName, dfs_JCR_SCIE[str(YEAR_REMARK)])
    if len(index_remark) == 0:
        index_remark = get_pub_index_eissn(info_scopus.eIssn, dfs_JCR_SCIE[str(YEAR_REMARK)])

    scie_yn = 'N'
    if len(index_remark) > 0:
        scie_yn = 'Y'
    else:
        scie_yn = 'N'
        print("SCIE 논문이 아닙니다.")
        continue
    
    df_applicants["논문구분\n(SCIE)"][i] = scie_yn
    
    year, date = regularize_date_publication(info_scopus.coverDisplayDate)
    df_applicants["Publication Date"][i] = date
    df_applicants["#citation"][i] = str(info_scopus.citedby_count)
    
    if year < YEAR_START:
        df_applicants["Notes"][i] = f"{YEAR_START-1} 이전 논문"
        continue
    
    elif year < YEAR_THIS:
        list_n = get_pub_index(info_scopus.publicationName, dfs_JCR_SCIE[str(year)])
        if len(list_n) > 0:
            index_n = list_n[0]
        else:
            list_n = get_pub_index_eissn(info_scopus.eIssn, dfs_JCR_SCIE[str(year)])
            if len(list_n) > 0:
                index_n = list_n[0]
            else:
                print("IF를 찾지 못했습니다.")
                continue
        jif_n = str(dfs_JCR_SCIE[str(year)]["IMPACT_FACTOR"][index_n])
    else:
        jif_n = f"{YEAR_THIS}년 출판으로 IF미발급"
        
    df_applicants["Publication Year journal impact factor"][i] = jif_n
    df_applicants["2020\njournal\nimpact\nfactor"][i] = str(dfs_JCR_SCIE[str(YEAR_REMARK)]["IMPACT_FACTOR"][index_remark[0]])
    
    ifp = dfs_JCR_SCIE[str(YEAR_REMARK)].loc[index_remark, "mrnIF"]
    try: 
        df_applicants["2020 journal impact factor percentile"][i] = str(ifp.values[0])
    except:
        df_applicants["2020 journal impact factor percentile"][i] = "mrnIF 없음"
    
    ### Author data
    authors_raw = np.array([regularize(n) for n in info_scopus.author_names.split(";")])
    
    list_name_eni = list_name_en[i]
    if "," not in list_name_eni: # 이름 성 
        list_name_eni_ = deepcopy(list_name_eni)
        list_name_eni_ = list_name_eni_.split(" ")
        list_name_eni = ", ".join(list_name_eni_[1:] + list_name_eni_[:1])
        
    try:
        idx_author = np.where(regularize(list_name_eni) == authors_raw)[0][0]
    except IndexError: # swap family and last name
        try:
            idx_author = np.where(regularize("".join(list_name_eni.split(",")[::-1])) == authors_raw)[0][0]
        except IndexError : # possibly disturbed by middle names
            idx_author=None
            author_name_words = regularize_space(list_name_eni).split(" ")
            name_words = [regularize_space(name).rstrip(" ").split(" ") for name in info_scopus.author_names.split(";")]
            for j, name_word in enumerate(name_words):
                name_check = list(set(author_name_words) - set(name_word))
                if len(name_check) == 0:
                    idx_author = j
                    df_applicants["Notes"][i] = "지원자 성명 확인 필요"
                    
    if idx_author == None:
        # 이니셜로만 되어있는건 아닌지 확인
        familyname = list_name_eni.split(", ")[0].lower()
        firstname = list_name_eni.split(", ")[1].lower()
        name_TF = [True if ((n[0] == familyname and len(set(n[1:])-set(firstname))==0) or 
                            (n[-1]==familyname and len(set(n[:-1])-set(firstname))==0)) 
                   else False 
                   for n in name_words]
        if len(np.where(np.array(name_TF)==True)[0]) > 0:
            idx_author = np.where(np.array(name_TF)==True)[0][0]
            df_applicants["Notes"][i] = "논문 저자 이름이 약어로 표현됨. 확인 필요."
            continue
        else:
            df_applicants["Notes"][i] = "지원자가 저자 명단에 없음"
            
        
    # first author    
    if idx_author == 0:
        first_author = list_name_eni
        first_author_yn = "Y"
    else:
        first_author = info_scopus.author_names.split(";")[0]
        first_author_yn = "N"    
    
    df_applicants["1st Author"][i] = first_author
    df_applicants["1ST AUTHOR\n(Y/N)"][i] = first_author_yn    
    df_applicants["1st Author"][i] = first_author
    
        
    ### Publication
    df_applicants["Source\n(Journal)"][i] = info_scopus.publicationName.upper()
    df_applicants["volume"][i] = info_scopus.volume
    
    if info_scopus.issueIdentifier != None:
        issue = info_scopus.issueIdentifier
    else:
        issue = ''
    df_applicants["issue"][i] = issue
    
    # PDF download
    accept = "application/pdf"
    HEADERS = {
        'X-ELS-APIKEY': APIKeys[-1],
        'Accept': accept
    }
    url = f'http://api.elsevier.com/content/article/doi:{doi}?view=FULL'
    with requests.get(url, stream=True, headers=HEADERS) as r:
        if r.status_code == 200: # download supported in Scopus
            if accept == "application/pdf":
                for chunk in r.iter_content(chunk_size=1024*1024):
                    with open(f"./pdf/paper_{i+1}.pdf", "wb") as f:
                        f.write(chunk)
            elif accept == "text/xml":
                xml = BeautifulSoup(r.content, "html5lib")
                xmls.append(xml)
                with open(f"./xml/xml_{i+1}.xml", "w") as f:
                    f.write(xml.prettify())

        elif r.status_code == 404: # not supported in Scopus
            print(f"# No.{i} is not available in Scopus.")
            
        # XML data mining
        url = f"https://doi.org/{doi}"
        r = requests.get(url)
        xml = BeautifulSoup(r.content, "html5lib")
        xmls.append(xml)            
        with open(f"./xml/xml_{i+1}.xml", "w") as f:
            f.write(xml.prettify())

    # write in every step
    df_applicants.to_excel("applicants_fill.xlsx", index=False)
    
print(len(xmls))
# Out:
# # No.0 is not available in Scopus.
# # No.6 is not available in Scopus.
# # No.7 is not available in Scopus.
# # No.8 is not available in Scopus.
# # No.9 is not available in Scopus.
# # No.10 is not available in Scopus.
# # No.11 is not available in Scopus.
# # No.12 is not available in Scopus.
# # No.13 is not available in Scopus.
# # No.14 is not available in Scopus.
# # No.15 is not available in Scopus.
# # No.16 is not available in Scopus.
# # No.17 is not available in Scopus.
# # No.18 is not available in Scopus.
# # No.19 is not available in Scopus.
# # No.20 is not available in Scopus.
# # No.21 is not available in Scopus.
# # No.22 is not available in Scopus.
# # No.23 is not available in Scopus.
# # No.24 is not available in Scopus.
# # No.25 is not available in Scopus.
# # No.26 is not available in Scopus.
# # No.27 is not available in Scopus.
# # No.28 is not available in Scopus.
# # No.29 is not available in Scopus.
# # No.30 is not available in Scopus.
# # No.31 is not available in Scopus.
# # No.32 is not available in Scopus.
# # No.33 is not available in Scopus.
# # No.34 is not available in Scopus.
# # No.35 is not available in Scopus.
# # No.36 is not available in Scopus.
# # No.37 is not available in Scopus.
# # No.38 is not available in Scopus.
# # No.39 is not available in Scopus.
# # No.40 is not available in Scopus.
# # No.41 is not available in Scopus.
# # No.42 is not available in Scopus.
# # No.43 is not available in Scopus.
# # No.44 is not available in Scopus.
# # No.45 is not available in Scopus.
# # No.46 is not available in Scopus.
# # No.47 is not available in Scopus.
# # No.48 is not available in Scopus.
# # No.49 is not available in Scopus.
# # No.50 is not available in Scopus.
# # No.51 is not available in Scopus.
# # No.52 is not available in Scopus.
# # No.53 is not available in Scopus.
# # No.54 is not available in Scopus.
# # No.55 is not available in Scopus.
# # No.56 is not available in Scopus.
# - No.57 is invalid.
# # No.58 is not available in Scopus.
# # No.59 is not available in Scopus.
# # No.60 is not available in Scopus.
# # No.61 is not available in Scopus.
# # No.62 is not available in Scopus.
# # No.63 is not available in Scopus.
# # No.64 is not available in Scopus.
# # No.65 is not available in Scopus.
# # No.66 is not available in Scopus.
# # No.67 is not available in Scopus.
# # No.68 is not available in Scopus.
# # No.69 is not available in Scopus.
# # No.70 is not available in Scopus.
# # No.71 is not available in Scopus.
# # No.72 is not available in Scopus.
# # No.73 is not available in Scopus.
# # No.74 is not available in Scopus.
# # No.75 is not available in Scopus.
# # No.76 is not available in Scopus.
# # No.77 is not available in Scopus.
# # No.78 is not available in Scopus.
# # No.79 is not available in Scopus.
# # No.80 is not available in Scopus.
# # No.81 is not available in Scopus.
# # No.82 is not available in Scopus.
# # No.83 is not available in Scopus.
# # No.84 is not available in Scopus.
# # No.85 is not available in Scopus.
# # No.86 is not available in Scopus.
# # No.87 is not available in Scopus.
# # No.88 is not available in Scopus.
# # No.89 is not available in Scopus.
# # No.90 is not available in Scopus.
# # No.91 is not available in Scopus.
# - No.92 is not accessible in Scopus.
# # No.93 is not available in Scopus.
# # No.94 is not available in Scopus.
# # No.95 is not available in Scopus.
# # No.96 is not available in Scopus.
# # No.97 is not available in Scopus.
# # No.98 is not available in Scopus.
# # No.99 is not available in Scopus.
# # No.100 is not available in Scopus.
# # No.101 is not available in Scopus.
# # No.102 is not available in Scopus.
# # No.103 is not available in Scopus.
# # No.104 is not available in Scopus.
# # No.105 is not available in Scopus.
# # No.106 is not available in Scopus.
# # No.107 is not available in Scopus.
# # No.108 is not available in Scopus.
# # No.109 is not available in Scopus.
# # No.110 is not available in Scopus.
# # No.111 is not available in Scopus.
# # No.112 is not available in Scopus.
# # No.113 is not available in Scopus.
# # No.114 is not available in Scopus.
# # No.115 is not available in Scopus.
# # No.117 is not available in Scopus.
# # No.118 is not available in Scopus.
# # No.119 is not available in Scopus.
# # No.120 is not available in Scopus.
# # No.121 is not available in Scopus.
# # No.122 is not available in Scopus.
# # No.123 is not available in Scopus.
# # No.124 is not available in Scopus.
# # No.125 is not available in Scopus.
# # No.126 is not available in Scopus.
# # No.127 is not available in Scopus.
# # No.128 is not available in Scopus.
# # No.129 is not available in Scopus.
# # No.130 is not available in Scopus.
# # No.131 is not available in Scopus.
# # No.132 is not available in Scopus.
# # No.133 is not available in Scopus.
# # No.134 is not available in Scopus.
# # No.135 is not available in Scopus.
# # No.136 is not available in Scopus.
# # No.137 is not available in Scopus.
# # No.138 is not available in Scopus.
# # No.139 is not available in Scopus.
# # No.140 is not available in Scopus.
# # No.141 is not available in Scopus.
# # No.142 is not available in Scopus.
# # No.143 is not available in Scopus.
# # No.144 is not available in Scopus.
# # No.145 is not available in Scopus.
# # No.147 is not available in Scopus.
# # No.148 is not available in Scopus.
# # No.150 is not available in Scopus.
# # No.151 is not available in Scopus.
# # No.152 is not available in Scopus.
# # No.153 is not available in Scopus.
# # No.154 is not available in Scopus.
# # No.155 is not available in Scopus.
# # No.156 is not available in Scopus.
# # No.157 is not available in Scopus.
# # No.158 is not available in Scopus.
# # No.159 is not available in Scopus.
# # No.160 is not available in Scopus.
# # No.161 is not available in Scopus.
# # No.162 is not available in Scopus.
# # No.163 is not available in Scopus.
# # No.164 is not available in Scopus.
# # No.165 is not available in Scopus.
# # No.166 is not available in Scopus.
# # No.167 is not available in Scopus.
# # No.168 is not available in Scopus.
# # No.169 is not available in Scopus.
# # No.170 is not available in Scopus.
# # No.171 is not available in Scopus.
# # No.172 is not available in Scopus.
# # No.173 is not available in Scopus.
# # No.174 is not available in Scopus.
# # No.175 is not available in Scopus.
# # No.176 is not available in Scopus.
# # No.177 is not available in Scopus.
# # No.178 is not available in Scopus.
# # No.179 is not available in Scopus.
# # No.180 is not available in Scopus.
# SCIE 논문이 아닙니다.
# # No.182 is not available in Scopus.
# # No.183 is not available in Scopus.
# # No.184 is not available in Scopus.
# # No.185 is not available in Scopus.
# # No.186 is not available in Scopus.
# # No.187 is not available in Scopus.
# # No.188 is not available in Scopus.
# # No.189 is not available in Scopus.
# # No.190 is not available in Scopus.
# # No.191 is not available in Scopus.
# # No.192 is not available in Scopus.
# # No.193 is not available in Scopus.
# # No.194 is not available in Scopus.
# # No.195 is not available in Scopus.
# # No.196 is not available in Scopus.
# # No.197 is not available in Scopus.
# # No.198 is not available in Scopus.
# # No.199 is not available in Scopus.
# # No.200 is not available in Scopus.
# # No.201 is not available in Scopus.
# # No.202 is not available in Scopus.
# # No.203 is not available in Scopus.
# # No.204 is not available in Scopus.
# # No.205 is not available in Scopus.
# # No.206 is not available in Scopus.
# # No.207 is not available in Scopus.
# # No.208 is not available in Scopus.
# # No.209 is not available in Scopus.
# - No.210 is invalid.
# # No.211 is not available in Scopus.
# # No.212 is not available in Scopus.
# # No.213 is not available in Scopus.
# # No.214 is not available in Scopus.
# # No.215 is not available in Scopus.
# # No.216 is not available in Scopus.
# # No.217 is not available in Scopus.
# # No.218 is not available in Scopus.
# # No.219 is not available in Scopus.
# # No.220 is not available in Scopus.
# # No.221 is not available in Scopus.
# # No.222 is not available in Scopus.
# # No.223 is not available in Scopus.
# # No.224 is not available in Scopus.
# # No.225 is not available in Scopus.
# # No.226 is not available in Scopus.
# - No.227 is invalid.
# # No.228 is not available in Scopus.
# # No.229 is not available in Scopus.
# # No.230 is not available in Scopus.
# # No.231 is not available in Scopus.
# # No.232 is not available in Scopus.
# # No.233 is not available in Scopus.
# # No.234 is not available in Scopus.
# - No.367 is invalid.
# SCIE 논문이 아닙니다.
# IF를 찾지 못했습니다.
# - No.475 is invalid.
# SCIE 논문이 아닙니다.
# - No.533 is invalid.
# SCIE 논문이 아닙니다.
# SCIE 논문이 아닙니다.
# - No.682 is invalid.
# SCIE 논문이 아닙니다.
# SCIE 논문이 아닙니다.
# SCIE 논문이 아닙니다.
# SCIE 논문이 아닙니다.
# # No.706 is not available in Scopus.
# # No.707 is not available in Scopus.
# # No.708 is not available in Scopus.
# # No.709 is not available in Scopus.
# # No.710 is not available in Scopus.
# # No.711 is not available in Scopus.
# # No.712 is not available in Scopus.
# # No.713 is not available in Scopus.
# # No.714 is not available in Scopus.
# # No.715 is not available in Scopus.
# # No.716 is not available in Scopus.
# - No.717 is invalid.
# # No.718 is not available in Scopus.
# # No.719 is not available in Scopus.
# # No.720 is not available in Scopus.
# # No.721 is not available in Scopus.
# # No.722 is not available in Scopus.
# # No.723 is not available in Scopus.
# # No.726 is not available in Scopus.
# # No.727 is not available in Scopus.
# # No.728 is not available in Scopus.
# # No.729 is not available in Scopus.
# # No.730 is not available in Scopus.
# # No.731 is not available in Scopus.
# # No.732 is not available in Scopus.
# # No.733 is not available in Scopus.
# # No.734 is not available in Scopus.
# # No.735 is not available in Scopus.
# # No.736 is not available in Scopus.
# # No.737 is not available in Scopus.
# # No.738 is not available in Scopus.
# # No.739 is not available in Scopus.
# # No.740 is not available in Scopus.
# # No.741 is not available in Scopus.
# # No.742 is not available in Scopus.
# # No.743 is not available in Scopus.
# # No.744 is not available in Scopus.
# # No.745 is not available in Scopus.
# # No.746 is not available in Scopus.
# # No.747 is not available in Scopus.
# # No.748 is not available in Scopus.
# # No.749 is not available in Scopus.
# # No.750 is not available in Scopus.
# # No.751 is not available in Scopus.
# # No.752 is not available in Scopus.
# # No.753 is not available in Scopus.
# SCIE 논문이 아닙니다.
# IF를 찾지 못했습니다.
# # No.756 is not available in Scopus.
# # No.757 is not available in Scopus.
# # No.758 is not available in Scopus.
# IF를 찾지 못했습니다.
# # No.760 is not available in Scopus.
# # No.761 is not available in Scopus.
# # No.762 is not available in Scopus.
# # No.763 is not available in Scopus.
# # No.764 is not available in Scopus.
# # No.765 is not available in Scopus.
# # No.766 is not available in Scopus.
# # No.767 is not available in Scopus.
# # No.768 is not available in Scopus.
# # No.769 is not available in Scopus.
# # No.770 is not available in Scopus.
# # No.771 is not available in Scopus.
# # No.772 is not available in Scopus.
# # No.773 is not available in Scopus.
# # No.774 is not available in Scopus.
# # No.775 is not available in Scopus.
# # No.776 is not available in Scopus.
# # No.777 is not available in Scopus.
# # No.778 is not available in Scopus.
# # No.779 is not available in Scopus.
# # No.780 is not available in Scopus.
# # No.781 is not available in Scopus.
# # No.782 is not available in Scopus.
# # No.783 is not available in Scopus.
# # No.784 is not available in Scopus.
# # No.785 is not available in Scopus.
# # No.786 is not available in Scopus.
# # No.787 is not available in Scopus.
# - No.788 is invalid.
# - No.789 is invalid.
# # No.790 is not available in Scopus.
# # No.791 is not available in Scopus.
# # No.792 is not available in Scopus.
# # No.793 is not available in Scopus.
# # No.794 is not available in Scopus.
# # No.795 is not available in Scopus.
# # No.796 is not available in Scopus.
# # No.797 is not available in Scopus.
# # No.798 is not available in Scopus.
# # No.799 is not available in Scopus.
# # No.800 is not available in Scopus.
# # No.801 is not available in Scopus.
# # No.802 is not available in Scopus.
# # No.803 is not available in Scopus.
# # No.804 is not available in Scopus.
# # No.805 is not available in Scopus.
# # No.806 is not available in Scopus.
# # No.807 is not available in Scopus.
# # No.808 is not available in Scopus.
# # No.809 is not available in Scopus.
# # No.810 is not available in Scopus.
# # No.811 is not available in Scopus.
# # No.812 is not available in Scopus.
# # No.813 is not available in Scopus.
# # No.814 is not available in Scopus.
# # No.815 is not available in Scopus.
# # No.816 is not available in Scopus.
# # No.817 is not available in Scopus.
# # No.818 is not available in Scopus.
# # No.819 is not available in Scopus.
# # No.820 is not available in Scopus.
# # No.821 is not available in Scopus.
# # No.822 is not available in Scopus.
# # No.823 is not available in Scopus.
# # No.824 is not available in Scopus.
# # No.825 is not available in Scopus.
# # No.826 is not available in Scopus.
# # No.827 is not available in Scopus.
# # No.828 is not available in Scopus.
# # No.829 is not available in Scopus.
# # No.830 is not available in Scopus.
# # No.831 is not available in Scopus.
# # No.832 is not available in Scopus.
# # No.833 is not available in Scopus.
# # No.834 is not available in Scopus.
# # No.835 is not available in Scopus.
# # No.836 is not available in Scopus.
# # No.837 is not available in Scopus.
# # No.838 is not available in Scopus.
# # No.839 is not available in Scopus.
# # No.840 is not available in Scopus.
# # No.841 is not available in Scopus.
# # No.842 is not available in Scopus.
# # No.843 is not available in Scopus.
# # No.844 is not available in Scopus.
# # No.845 is not available in Scopus.
# # No.846 is not available in Scopus.
# # No.847 is not available in Scopus.
# # No.848 is not available in Scopus.
# # No.849 is not available in Scopus.
# # No.850 is not available in Scopus.
# # No.851 is not available in Scopus.
# # No.852 is not available in Scopus.
# # No.853 is not available in Scopus.
# # No.854 is not available in Scopus.
# # No.855 is not available in Scopus.
# # No.856 is not available in Scopus.
# # No.857 is not available in Scopus.
# # No.858 is not available in Scopus.
# # No.859 is not available in Scopus.
# # No.860 is not available in Scopus.
# # No.861 is not available in Scopus.
# # No.862 is not available in Scopus.
# # No.863 is not available in Scopus.
# # No.864 is not available in Scopus.
# # No.865 is not available in Scopus.
# # No.866 is not available in Scopus.
# # No.867 is not available in Scopus.
# # No.868 is not available in Scopus.
# # No.869 is not available in Scopus.
# IF를 찾지 못했습니다.
# # No.871 is not available in Scopus.
# # No.872 is not available in Scopus.
# # No.873 is not available in Scopus.
# # No.874 is not available in Scopus.
# # No.875 is not available in Scopus.
# - No.876 is invalid.
# # No.877 is not available in Scopus.
# # No.878 is not available in Scopus.
# # No.879 is not available in Scopus.
# # No.880 is not available in Scopus.
# # No.881 is not available in Scopus.
# # No.882 is not available in Scopus.
# # No.883 is not available in Scopus.
# # No.884 is not available in Scopus.
# # No.885 is not available in Scopus.
# # No.886 is not available in Scopus.
# # No.887 is not available in Scopus.
# # No.888 is not available in Scopus.
# # No.889 is not available in Scopus.
# # No.890 is not available in Scopus.
# # No.891 is not available in Scopus.
# # No.892 is not available in Scopus.
# # No.894 is not available in Scopus.
# # No.895 is not available in Scopus.
# # No.896 is not available in Scopus.
# # No.897 is not available in Scopus.
# # No.898 is not available in Scopus.
# # No.899 is not available in Scopus.
# # No.900 is not available in Scopus.
# # No.901 is not available in Scopus.
# # No.902 is not available in Scopus.
# # No.903 is not available in Scopus.
# - No.904 is invalid.
# # No.905 is not available in Scopus.
# # No.906 is not available in Scopus.
# # No.907 is not available in Scopus.
# # No.908 is not available in Scopus.
# # No.909 is not available in Scopus.
# # No.910 is not available in Scopus.
# # No.911 is not available in Scopus.
# # No.912 is not available in Scopus.
# # No.913 is not available in Scopus.
# # No.914 is not available in Scopus.
# # No.915 is not available in Scopus.
# # No.916 is not available in Scopus.
# # No.917 is not available in Scopus.
# # No.918 is not available in Scopus.
# # No.919 is not available in Scopus.
# # No.920 is not available in Scopus.
# # No.921 is not available in Scopus.
# # No.922 is not available in Scopus.
# # No.923 is not available in Scopus.
# # No.924 is not available in Scopus.
# # No.925 is not available in Scopus.
# - No.926 is invalid.
# # No.927 is not available in Scopus.
# # No.928 is not available in Scopus.
# # No.929 is not available in Scopus.
# # No.930 is not available in Scopus.
# # No.931 is not available in Scopus.
# # No.932 is not available in Scopus.
# # No.933 is not available in Scopus.
# # No.934 is not available in Scopus.
# # No.935 is not available in Scopus.
# # No.936 is not available in Scopus.
# # No.937 is not available in Scopus.
# # No.938 is not available in Scopus.
# # No.939 is not available in Scopus.
# # No.940 is not available in Scopus.
# # No.941 is not available in Scopus.
# # No.942 is not available in Scopus.
# # No.943 is not available in Scopus.
# # No.944 is not available in Scopus.
# # No.945 is not available in Scopus.
# # No.946 is not available in Scopus.
# # No.949 is not available in Scopus.
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# /opt/conda/lib/python3.7/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# /opt/conda/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# /opt/conda/lib/python3.7/http/client.py in _read_status(self)
#     274             # sending a valid response.
# --> 275             raise RemoteDisconnected("Remote end closed connection without"
#     276                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     724             retries = retries.increment(
# --> 725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     726             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/conda/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# /opt/conda/lib/python3.7/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# /opt/conda/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# /opt/conda/lib/python3.7/http/client.py in _read_status(self)
#     274             # sending a valid response.
# --> 275             raise RemoteDisconnected("Remote end closed connection without"
#     276                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-14-dda51e3dc082> in <module>
#     154         # XML data mining
#     155         url = f"https://doi.org/{doi}"
# --> 156         r = requests.get(url)
#     157         xml = BeautifulSoup(r.content, "html5lib")
#     158         xmls.append(xml)
#
# /opt/conda/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/conda/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     663
#     664         # Resolve redirects if allowed.
# --> 665         history = [resp for resp in gen] if allow_redirects else []
#     666
#     667         # Shuffle things around if there's history.
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in <listcomp>(.0)
#     663
#     664         # Resolve redirects if allowed.
# --> 665         history = [resp for resp in gen] if allow_redirects else []
#     666
#     667         # Shuffle things around if there's history.
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     243                     proxies=proxies,
#     244                     allow_redirects=False,
# --> 245                     **adapter_kwargs
#     246                 )
#     247
#
# /opt/conda/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/conda/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %%
i
# Out:
# 949

# %%
doi
# Out:
# '10.1039/C6DT04466B'

# %%
list_doi[i]

# %%
year

# %%
dfs_JCR_SCIE[str(year)]["ISSN"]

# %%
info_scopus.issn

# %%
info_scopus.publicationName

# %%
dfs_JCR_SCIE[str(year)]["EISSN"]

# %%
doi = "10.1039/C6DT04466B"
s = ScopusSearch(f"DOI ({doi})", download=True, subscriber=subscriber).results
info_scopus = s[0]
index_remark_eissn = get_pub_index_eissn(info_scopus.eIssn, dfs_JCR_SCIE[str(YEAR_REMARK)])
print(index_remark_eissn)
index_remark = get_pub_index(info_scopus.publicationName, dfs_JCR_SCIE[str(YEAR_REMARK)])
print(index_remark)
# Out:
# [6302]
# [6302]

# %%
info_scopus = s[0]

index_remark = get_pub_index(info_scopus.publicationName, dfs_JCR_SCIE[str(YEAR_REMARK)])
if len(index_remark) == 0:
    index_remark = get_pub_index_eissn(info_scopus.eIssn, dfs_JCR_SCIE[str(YEAR_REMARK)])

# %%
index_remark

# %%
title

# %%
info_scopus.publicationName

# %%
"Progress in Photovoltaics".lower() in [v.lower() for v in dfs_JCR_SCIE[str(YEAR_REMARK)]["TITLE"].values]

# %%
s

# %%
info_scopus.eIssn

# %%
info_scopus.eIssn in dfs_JCR_SCIE[str(YEAR_REMARK)]["EISSN"].str.replace("-","").values

# %%
dfs_JCR_SCIE[str(YEAR_REMARK)]["EISSN"]

# %%
df_A = pd.DataFrame({"X":[1,2,3,4,5], "Y":[11,12,13,14,15]})
df_B = pd.DataFrame({"X":[1,2,3,5,6], "Y":[11,12,13,15,16]})
df_C = pd.DataFrame({"X":[2,3,5,6,7], "Y":[12,13,15,16,17], "Z":[22,23,25,26,27]})

# %%
df_A.merge(df_C, how="left")

# %%
dfs_JCR_SCIE["2018"].head(3)

# %%
dfs_JCR_SCIE["2017"].head(3)

# %%
dfs_JCR_SCIE["2020"].head(3)
